# %% [markdown]
# # Assignment Brief: Probabilistic Programming and Active Learning
#
# ## Deadline: May 7, 2025, 17:00 GMT
#
# ## Number of marks available: 50
#
# This coursework is made of two parts. In the first part, you will use probabilistic programming to perform Bayesian inference in different models. In the second part, you will use uncertainty to guide datapoint selection to create a dataset to train a machine learning model.
#
# ### Please READ the whole assignment first, before starting to work on it.
#
# ### How and what to submit
#
# A. A **Jupyter Notebook** with the code in all the cells executed and outputs displayed.
#
# B. Name your Notebook **COM64102_Assignment_XXXXXX.ipynb** where XXXXXX is your username such as such as abc18de. Example: `COM64102_Assignment_abc18de.ipynb`
#
# C. Upload the Jupyter Notebook in B to Blackboard under the submission area before the deadline.
#
# D. **NO DATA UPLOAD**: Please do not upload the data files used in this Notebook. We have a copy already.
#
#
# ### Assessment Criteria
#
# * Being able to compute the posterior distribution in Bayesian logistic regression using a probabilistic program.
#
# * Being able to compute several acquisition functions useful for active learning.
#
# * Being able to use active learning to speed-up the training process of a digit classifier.
#
#
# ### Code quality and use of Python libraries
# When writing your code, you will find out that there are operations that are repeated at least twice. If your code is unreadable, we may not award marks for that section. Make sure to check the following:
#
# * Did you include Python functions to solve the question and avoid repeating code?
# * Did you comment your code to make it readable to others?
#
# ### Late submissions
#
# We follow Department's guidelines about late submissions, i.e., a deduction of 10% of the mark each 24 hours the work is late after the deadline. NO late submission will be marked one week after the deadline. Please read [this link](https://wiki.cs.manchester.ac.uk/index.php/UGHandbook23:Main#Late_Submission_of_Coursework_Penalty).
#
# ### Use of unfair means
#
# **Any form of unfair means is treated as a serious academic offence and action may be taken under the Discipline Regulations.** Please carefully read [what constitutes Unfair Means](https://documents.manchester.ac.uk/display.aspx?DocID=2870) if not sure. If you still have questions, please ask your Personal tutor or the Lecturers.

# %% [markdown]
# # 1. Probabilistic Programming with PyMC
#
# [PyMC](https://www.pymc.io/) is a powerful Python library for **Bayesian statistical modeling** and **probabilistic machine learning**. It provides an intuitive and flexible way to define complex models using a **probabilistic programming framework**.
#
# PyMC makes it easy to express statistical models in terms of probability distributions, and it automates the process of computing posterior distributions using state-of-the-art Markov Chain Monte Carlo (MCMC) sampling methods like:
# - [**No-U-Turn Sampler (NUTS)**](https://jmlr.org/papers/volume15/hoffman14a/hoffman14a.pdf), an efficient Hamiltonian Monte Carlo method.
# - **Metropolis-Hastings** ‚ a traditional and widely-used MCMC approach.
#
# Bayesian inference involves calculating the posterior distribution:
# $$
# P(\theta | X) \propto P(X | \theta)P(\theta)
# $$
# where:
# - $P(\theta)$‚ a prior distribution (our prior belief about the parameters).
# - $P(X | \theta)$‚ a likelihood of the data given the parameters.
# - $P(\theta | X)$, a posterior distribution (what we want to estimate).
#
# Computing this posterior distribution analytically can be difficult or even impossible for complex models. PyMC solves this problem by using efficient numerical sampling techniques, allowing you to approximate the posterior distribution and extract meaningful insights.
#
# ## How Does PyMC Work?
# 1. **Model Definition**: Define the model using PyMC probabilistic building blocks (e.g., `pm.Normal`, `pm.Bernoulli`).
# 2. **Sampling**: Use `pm.sample()` to draw samples from the posterior distribution.
# 3. **Posterior Analysis**: Analyze the posterior samples to estimate parameters, uncertainties, and credible intervals.
#
# PyMC builds on [**Theano**](https://en.wikipedia.org/wiki/Theano_(software)), which allows it to compute gradients and perform symbolic differentiation for more efficient sampling.

# %% [markdown]
# ## 1.1 Bayesian inference over the mean of a Gaussian using PyMC
#
# In [Lab 1 for this module](https://colab.research.google.com/github/m-caprio/COMP64102-Reasoning-and-Learning-under-Uncertainty-Module/blob/main/New%20Lab%201.ipynb), you computed the posterior distribution over the mean of a Gaussian distribution in closed form using the fact that the Gaussian likelihood and the prior over the mean of the Gaussian likelihood are conjugate. The equation for the mean of the posterior distribution had a closed form.
#
# As a warm up example in the use of PyMC, we will do the same example using the probabilistic programming language. Refer to [Lab 1](https://colab.research.google.com/github/m-caprio/COMP64102-Reasoning-and-Learning-under-Uncertainty-Module/blob/main/New%20Lab%201.ipynb) when reading forward.

# %% [markdown]
# Besides installing PyMC, we will also install the [ArViz](https://python.arviz.org/en/stable/) package, which is used for exploratory analysis of Bayesian models.

# %%
# !pip install pymc
import pymc as pm
import arviz as az
# Out:
# Requirement already satisfied: pymc in /usr/local/lib/python3.11/dist-packages (5.21.1)
# Requirement already satisfied: arviz>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from pymc) (0.21.0)
# Requirement already satisfied: cachetools>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from pymc) (5.5.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pymc) (3.1.1)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from pymc) (2.0.2)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from pymc) (2.2.2)
# Requirement already satisfied: pytensor<2.29,>=2.28.2 in /usr/local/lib/python3.11/dist-packages (from pymc) (2.28.3)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.11/dist-packages (from pymc) (13.9.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pymc) (1.14.1)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from pymc) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pymc) (4.12.2)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.13.0->pymc) (75.1.0)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.13.0->pymc) (3.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from arviz>=0.13.0->pymc) (24.2)
# Requirement already satisfied: xarray>=2022.6.0 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.13.0->pymc) (2025.1.2)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.13.0->pymc) (1.6.1)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.11/dist-packages (from arviz>=0.13.0->pymc) (0.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->pymc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->pymc) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->pymc) (2025.1)
# Requirement already satisfied: filelock>=3.15 in /usr/local/lib/python3.11/dist-packages (from pytensor<2.29,>=2.28.2->pymc) (3.18.0)
# Requirement already satisfied: etuples in /usr/local/lib/python3.11/dist-packages (from pytensor<2.29,>=2.28.2->pymc) (0.3.9)
# Requirement already satisfied: logical-unification in /usr/local/lib/python3.11/dist-packages (from pytensor<2.29,>=2.28.2->pymc) (0.4.6)
# Requirement already satisfied: miniKanren in /usr/local/lib/python3.11/dist-packages (from pytensor<2.29,>=2.28.2->pymc) (1.0.3)
# Requirement already satisfied: cons in /usr/local/lib/python3.11/dist-packages (from pytensor<2.29,>=2.28.2->pymc) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->pymc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->pymc) (2.18.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc) (3.13.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc) (1.17.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from logical-unification->pytensor<2.29,>=2.28.2->pymc) (0.12.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from logical-unification->pytensor<2.29,>=2.28.2->pymc) (1.0.0)

# %% [markdown]
# The following code uses PyMC to obtain samples from the posterior distribution of the mean of the Gaussian

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Observed data (assumed to be generated from a Gaussian distribution)
data = np.array([3.2, 2.8, 3.6, 3.0, 3.1, 2.9, 3.3, 3.5])

# Known standard deviation of the data
sigma = 0.5

# Define the model in PyMC
with pm.Model() as model:
    # Prior for mu (mean) - assume Gaussian prior
    mu_0 = 3.0  # Prior mean
    sigma_0 = 1.0  # Prior standard deviation
    mu = pm.Normal('mu', mu=mu_0, sigma=sigma_0) # Prior

    # Likelihood for the data - assume Gaussian likelihood
    likelihood = pm.Normal('likelihood', mu=mu, sigma=sigma, observed=data) # Likelihood

    # Sample from the posterior distribution
    trace = pm.sample(2000, return_inferencedata=True)

# Extract posterior samples
mu_p_samples = trace.posterior['mu'].values.flatten()

# Compute posterior mean and standard deviation
mu_p = np.mean(mu_p_samples)
sigma_p = np.std(mu_p_samples)

# Print results
print(f"Posterior mean (mu_p): {mu_p:.2f}")
print(f"Posterior standard deviation (sigma_p): {sigma_p:.2f}")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Posterior mean (mu_p): 3.17
# Posterior standard deviation (sigma_p): 0.17

# %% [markdown]
# The values for the posterior mean and posterior standard deviation when comparing the exact solution in Lab 1 and the sampling approach using PyMC are the same.
#
# **Question 1 (5 marks)**
#
# What is the fundamental difference between the approach to compute the mean of the posterior distribution in Lab 1 and the approach to compute the mean using PyMC.
#
# *Solution*
#
# The solution to compute the mean of the posterior distribution in Lab 1 required finding an analytical expression of the mean by completing the square from the likelihood and the prior, both Gaussians. Since the problem is conjugate, then the analytical expression can be found after some mathematical manipulations. Using PyMC, the posterior distribution is found using sampling and the samples are then used to compute the mean and standard deviation of the posterior.

# %% [markdown]
# We can now plot the prior, likelihood and the posterior pdf's.

# %%
# Plot prior, likelihood, and posterior
x = np.linspace(2, 4, 1000)  # Range of mu values to plot
prior = norm.pdf(x, mu_0, sigma_0)  # Prior distribution
likelihood = norm.pdf(x, np.mean(data), sigma / np.sqrt(len(data)))  # Likelihood
posterior = norm.pdf(x, mu_p, sigma_p)  # Posterior distribution

plt.figure(figsize=(10, 6))
plt.plot(x, prior, label="Prior", linestyle="--")
plt.plot(x, likelihood, label="Likelihood", linestyle="-.")
plt.plot(x, posterior, label="Posterior", linestyle="-")
plt.title("Bayesian Update of Gaussian Mean (PyMC)")
plt.xlabel("Mean ($\mu$)")
plt.ylabel("Probability Density")
plt.legend()
plt.show()

# %% [markdown]
# Two metrics to assess convergence in MCMC are the **effective sample size** (ESS) and the **estimated potential scale reduction** (EPSRC) or **R-hat**.

# %% [markdown]
# We can use the [ArViz](https://python.arviz.org/en/stable/) package to compute both quantities.

# %%
# Posterior summary (for more detailed diagnostics)
print(az.summary(trace, var_names=["mu"], hdi_prob=0.95))
# Out:
#      mean     sd  hdi_2.5%  hdi_97.5%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# mu  3.167  0.174     2.824      3.506      0.004    0.003    1817.0    2646.0
#
#     r_hat
# mu    1.0

# %% [markdown]
# **Question 2 (5 marks)**
#
# The value of `r_hat` for the mean is equal to 1.0. Explain what `r_hat` computes and whether 1.0 is a good value. Explain why it is or why it is not a good value.

# %% [markdown]
# *Solution*
#
# In ArViz, `r-hat` makes reference to the rank normalized splitR-hat diagnostic test. It basically compares the variance between multiple chains and the variance within each chain. The intuition is that if one or more chains have not mixed well, the variance of all the chains combined together will be higher than the variance of the individual chains. It also splits each individual chain into the first and second halves, doubling the number of chains. A value of`r-hat` close to 1.0 indicates a good convergence for the MCMC sampling.

# %% [markdown]
# ## 1.2 Bayesian logistic regression with PyMC
#
# In the previous module in Foundations of Machine Learning, we spent some time on a linear model for classification called **logistic regression**.
#
# In a binary classification problem, let $\mathbf{X}=[\mathbf{x}_1 \cdots \mathbf{x}_N]^\top$ and and $\mathbf{y} =[y_1\cdots y_N]^{\top}$, where $\mathbf{X}$ is the design matrix and each element in $\mathbf{y}$, say $y_n$ indicates to which class the corresponding input vector, $\mathbf{x}_n$, belongs to.
#
# Assumming IID observations, the likelihood for the dataset is given as
# \begin{align*}
# p(\mathbf{y}|\mathbf{w},\mathbf{X}) = \prod_{n=1}^Np(y_n|\mathbf{w},\mathbf{x}_n)
#   =\prod_{n=1}^N\textrm{Ber}(y_n|\sigma(\mathbf{w}^{\top}\mathbf{x}_n)),
# \end{align*}
# where $\textrm{Ber}(y_n|\mu)$ refers to the Bernoulli distribution with parameter $\mu$, and $\sigma(a)$ is the sigmoid function defined as $\sigma(a)=\frac{1}{1+ \exp(-a)}$.
#
# The maximum-likelihood estimator for $\mathbf{w}$ can be obtained by minimising the negative log-likelihood (or the cross-entropy function) given as
#
# \begin{align*}
# NLL(\mathbf{w}) & = - \log p(\mathbf{y}|\mathbf{w},\mathbf{X}) \\
# & = - \sum_{n=1}^N\{y_n\log[\sigma(\mathbf{w}^{\top}\mathbf{x}_n)] + (1-y_n)\log[1 - \sigma(\mathbf{w}^{\top}\mathbf{x}_n)] \}.
# \end{align*}
#
# In *Bayesian logistic regression*, we put a prior over the weights $\mathbf{w}$. We then compute the posterior distribution
# \begin{align*}
# p(\mathbf{w}|\mathbf{X}, \mathbf{y}) \propto p(\mathbf{y}|\mathbf{w}, \mathbf{X})p(\mathbf{w}).
# \end{align*}
# For predicting the class of a text point, $\mathbf{x}_*$, we need to compute the predictive distribution,
# \begin{align}
# p(y_*|\mathbf{x}_*)=\int \sigma(\mathbf{w}^{\top}\mathbf{x}_*)p(\mathbf{w}|\mathbf{X}, \mathbf{y})d\mathbf{w}.
# \end{align}
#
# If we approximate the posterior distribution $p(\mathbf{w}|\mathbf{X}, \mathbf{y})$ with a Gaussian posterior distribution,
# \begin{align*}
# p(\mathbf{w}|\mathbf{X}, \mathbf{y}) ≈ q(\mathbf{w}|\mathbf{X}, \mathbf{y}) = N(\mathbf{w}|𝛍_{\text{post}}, 𝚺_{\text{post}}),
# \end{align*}
# it can be shown the predictive distribution can also be approximated as
# \begin{align*}
# p(y_*=1|\mathbf{x}_*) = \sigma(\kappa (\sigma^2_a)\mu_a),
# \end{align*}
# where
# \begin{align*}
# \mu_a &= 𝛍_{\text{post}}^\top\mathbf{x}_*,\\
# \sigma_a^2 &= \mathbf{x}^\top_*𝚺_{\text{post}}\mathbf{x}_*,\\
# \kappa(\sigma^2) &= \frac{1}{(1+\pi \sigma^2/8)^{\frac{1}{2}}}
# \end{align*}
#
#
# ### Bayesian logistic regression for the Iris dataset
#
# To illustrate how Bayesian logistic regression works, we will use a very well known dataset, the [Iris dataset](https://archive.ics.uci.edu/dataset/53/iris). The dataset has three classes and four input features. We will only use two classes.

# %% [markdown]
# Let us load the dataset

# %%
# !pip install ucimlrepo
from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X3 = iris.data.features
y3 = iris.data.targets
# Drop the last class and the last two columns
Xp = X3.drop(X3.index[100:150])
yp = y3.drop(y3.index[100:150])
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %% [markdown]
# We now have a reduced dataset that we will split into training and test

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
# We add a vector of ones to the input space in X
X = Xp.to_numpy()
# Add a column of ones to X
y = np.vstack((np.zeros((50, 1)), np.ones((50, 1))))
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=int(1e3))
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **Question 3 (10 marks)**
#
# Let us define the following prior distribution for $\mathbf{w}$, $p(\mathbf{w})= N(\mathbf{w}|\mathbf{0}_4, 0.001\times \mathbf{I}_4)$, where $\mathbf{0}_4 = [0, 0, 0, 0]^\top$ and $\mathbf{I}_4$ is the identity matrix of dimension four since there are four input features.
#
# Using the training data `X_train` and `y_train`, compute an approximate posterior Gaussian distribution using PyMC for a Bayesian logistic regression model. Use 2000 samples for the sampler and report the mean and the covariance matrix for the approximate Gaussian using the last 1000 samples of one of the chains (**7 marks**)

# %% [markdown]
# *Solution*

# %%
with pm.Model() as model:
    # Priors for the coefficients (Normal distribution)
    weights = pm.Normal("weights", mu=0, sigma=0.031, shape=(X_train.shape[1],))

    # Logistic model for the likelihood
    p = pm.math.sigmoid(pm.math.dot(X_train, weights))

    # Bernoulli likelihood for observed data
    y_obs = pm.Bernoulli("y_obs", p=p, observed=y_train)

    # Sample from the posterior distribution using MCMC
    trace = pm.sample(2000, return_inferencedata=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
samples = trace.posterior["weights"].values # Extract the samples from trace
mean_post = np.mean(samples[0,1000:1999, :], axis=0) # Use the first chain and the last 1000 samples to compute the posterior mean
cov_post = np.cov(samples[0,1000:1999, :], rowvar=False) # Use the first chain and the last 1000 samples to compute the posterior covariance

# %% [markdown]
# Compute the accuracy of the linear classifier over the test set using the approximated distribution $p(y_*=1|\mathbf{x}_*) = \sigma(\kappa (\sigma^2_a)\mu_a)$, as explained above (**3 marks**).

# %%
mu_a = X_test @  mean_post[:, np.newaxis]
sigma_a2 = np.diag(X_test @ cov_post @ X_test.T)[:, np.newaxis]
kappa_sigma_a2 = 1/np.sqrt(1 + np.pi*sigma_a2/8)
p_test = 1/(1 + np.exp(-kappa_sigma_a2*mu_a))
y_pred = 1 - (p_test > 0.5).astype(int)
accuracy = np.mean(y_pred == y_test)

# %% [markdown]
# # 2. Active Learning -- Using data selection via uncertainty to keep models fresh
#
# We can use
# uncertainties to figure out whether data should be part of the training data
# or not. We can expand on this idea in the context of an area of
# machine learning called **active learning**. The promise of active
# learning is that a model can learn more eﬀectively on less data if we
# have a way to control the type of data it is trained on. Active learning is a way to
# guide the learning process and data a model is trained on by
# **providing acquisition functions** that can acquire data from a pool of data that is
# not part of the training data. By iteratively selecting the right data
# from the pool, we can train a model that performs better than if we
# had chosen the data from the pool at random.
#
# The active learning approach can be described with the following iterative procedure
# ```
# A model is initially trained using a few samples per class
# for iter until a fixed number of iterations:
#   compute an acquisition function over the data in the pool
#   based on the acquisition function select a sample to include in the
#      training data
#   train the model again using the augmented training data
# ```
#
# In this part of the coursework, we will use results from a fundamental
# active learning paper: [Deep Bayesian Active Learning with Image Data
# (2017)](https://arxiv.org/abs/1703.02910). We will use the MNIST dataset and train a model on more
# and more data, where we select the data points to add to our
# training set via an uncertainty method. In this case, we will use **epistemic uncertainty** to select the most informative data points.
# Images with high epistemic uncertainty will be added to the traininig dataset in a sequential manner. The epistemic uncertainty can be computed using different methods. You will use **Monte Carlo dropout** and will compare the performance of using epistemic uncertainty to introduce new points in the training data against including new training points just but randomly selecting from a pool of available data.
#
# **IMPORTANT** To reduce the amount of code appearing in the notebook, we have created a set of python modules that include auxiliary functions. You need to make sure when running the notebook that your Google Drive is mounted and the auxiliar Python files can be accessed from the Notebook. On how to allow your Notebook to find the .py files in your Google Drive, see instructions in this [link](https://nimbusintelligence.com/2023/03/import-python-scripts-in-google-colab/)

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
# The path here can be different, depending on where you have uploaded the auxiliary Python files.
sys.path.insert(0,'/content/drive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We start by importing a set of modules

# %%
import dataclasses
from typing import Optional, Tuple, Union, Callable
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import torchvision
from tqdm import tqdm
import json
from pathlib import Path
import gc
import uuid
import matplotlib.pyplot as plt

# %%
# !pip install laplace-torch
from laplace import Laplace
# Out:
# Requirement already satisfied: laplace-torch in /usr/local/lib/python3.11/dist-packages (0.2.2.2)
# Requirement already satisfied: asdfghjkl==0.1a4 in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (0.1a4)
# Requirement already satisfied: backpack-for-pytorch in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (1.7.1)
# Requirement already satisfied: curvlinops-for-pytorch>=2.0 in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (1.26.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (3.4.0)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (2.6.0+cu124)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (1.7.0)
# Requirement already satisfied: torchvision>=0.15 in /usr/local/lib/python3.11/dist-packages (from laplace-torch) (0.21.0+cu124)
# Requirement already satisfied: scipy<2.0.0,>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch>=2.0->laplace-torch) (1.14.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.61.0 in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch>=2.0->laplace-torch) (4.67.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch>=2.0->laplace-torch) (0.8.1)
# Requirement already satisfied: einconv in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch>=2.0->laplace-torch) (0.1.0)
# Requirement already satisfied: unfoldNd<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from backpack-for-pytorch->laplace-torch) (0.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->laplace-torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0->laplace-torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.15->laplace-torch) (11.1.0)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics->laplace-torch) (24.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics->laplace-torch) (0.14.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics->laplace-torch) (75.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0->laplace-torch) (3.0.2)

# %% [markdown]
# ## 2.1 Preparing the dataset
#
# We work with the MNIST dataset.

# %%
from data import get_data, prepare_data_loaders

# Get preprocessed MNIST data
data = get_data()

# Create PyTorch DataLoaders
train_loader, test_loader = prepare_data_loaders(data, batch_size=64)

# Function to display a grid of images
def display_mnist_samples(images, labels, grid_size=(3, 3)):
    fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=(8, 8))

    for i, ax in enumerate(axes.flat):
        if i < len(images):
            # Remove the extra dimension and display the image
            ax.imshow(images[i].squeeze(), cmap='gray')
            # Get the original label (not one-hot encoded)
            label = np.argmax(labels[i])
            ax.set_title(f"Digit: {label}")
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# Display a few samples from the training set
num_samples = 9
indices = np.random.choice(len(data.x_train), num_samples, replace=False)
sample_images = data.x_train[indices]
sample_labels = data.y_train[indices]

# Display the images
display_mnist_samples(sample_images, sample_labels)

# Print some information about the dataset
print(f"Total training samples: {len(data.x_train)}")
print(f"Total test samples: {len(data.x_test)}")
# Out:
# Total training samples: 60000
# Total test samples: 10000

# %% [markdown]
# ## 2.2 Defining the model
#
# We can now define our model. We will use a small, simple Convolutional Neural Network with dropout as shown below:
#
# ```
# class MNISTModel(nn.Module):
#     def __init__(self):
#         super(MNISTModel, self).__init__()
#         self.conv_layers = nn.Sequential(
#             nn.Conv2d(1, 32, kernel_size=4, padding=0),
#             nn.ReLU(),
#             nn.Conv2d(32, 32, kernel_size=4, padding=0),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size=2),
#             nn.Dropout(0.25)
#         )
#
#         self.fc_layers = nn.Sequential(
#             nn.Linear(3872, 128),
#             nn.ReLU(),
#             nn.Dropout(0.5),
#             nn.Linear(128, 10)
#         )
#
#     def forward(self, x):
#         x = x.permute(0, 3, 1, 2)
#         x = self.conv_layers(x)
#         x = torch.flatten(x, 1)
#         x = self.fc_layers(x)
#         return x
#
# def build_model():
#     model = MNISTModel()
#     return model
#
# ```
# This network model has been defined in the file `model.py` and we will call it later.

# %% [markdown]
# ## 2.3 Defining the uncertainty functions
#
# ### 2.3.1 Epistemic or knowledge uncertainty
#
# We will use epistemic uncertainty (also called knowledge
# uncertainty) as one of our main uncertainty functions to acquire new
# samples. Let us define the function to compute epistemic uncertainty
# over our predictions.
#
# We define the followoing terms and notations:
# - $\omega$: Model parameters (weights and biases)
# - $p(y = c|x, \omega)$: Probability of input $x$ belonging to class $c$ with model parameters $\omega$
# - $q_\theta^*(\omega)$: Approximate posterior distribution over model parameters
# - $\hat{\omega}_t \sim q_\theta^*(\omega)$: A sample of weights drawn from the approximate posterior
# - $\hat{p}_c^t = p(y = c|x, \hat{\omega}_t)$: Predicted probability for class $c$ using sampled weights $\hat{\omega}_t$ in MC dropout
# - $T$: Total number of Monte Carlo dropout forward passes
# - $C$: Number of classes
#
# ### Total Uncertainty
#
# The total predictive uncertainty is captured by the entropy of the expected predictive distribution (Max Entropy, (Shannon, 1948)):
#
# $$H[y|x, D_{\text{train}}] = -\sum_{c} p(y = c|x, D_{\text{train}}) \log p(y = c|x, D_{\text{train}})$$
#
# This can be approximated using $T$ forward passes with MC dropout:
#
# $$H[y|x, D_{\text{train}}] \approx -\sum_{c} \left(\frac{1}{T}\sum_{t=1}^{T} \hat{p}_c^t\right) \log \left(\frac{1}{T}\sum_{t=1}^{T} \hat{p}_c^t\right)$$
#
# ### Data Uncertainty (Aleatoric)
#
# Data uncertainty represents the inherent noise in the data, approximated as the expected entropy of individual predictions (Gal, 2016, pp. 48–52):
#
# $$E_{p(\omega|D_{\text{train}})}[H[y|x, \omega]] \approx \frac{1}{T}\sum_{t=1}^{T} \left(-\sum_{c} \hat{p}_c^t \log \hat{p}_c^t\right)$$
#
# ### Knowledge Uncertainty (Epistemic)
#
# Knowledge uncertainty is the mutual information between predictions and model posterior, which is the BALD acquisition function (Houlsby et al., 2011) in the paper (which is Total `Uncertainty` - `Data Uncertainty`) :
#
# $$I[y, \omega|x, D_{\text{train}}] = H[y|x, D_{\text{train}}] - E_{p(\omega|D_{\text{train}})}[H[y|x, \omega]]$$
#
# This quantity represents the uncertainty in the model parameters, which can be reduced by acquiring more data. This is why it serves as an effective acquisition function for active learning.

# %% [markdown]
# Knowledge uncertainty will be used as acquisition function in the active learning loop. To compute it, we first need the weights obtained through MC dropout.
#
# `get_mc_predictions` uses MC droupout to generate the necessary prediction distribution (multiple predictions per sample) that the uncertainty functions need as input. It creates the `preds` tensor $\hat{p}_c^t$ with shape (n_samples, n_mc_passes, n_classes) that is directly passed to `total_uncertainty`, `data_uncertainty`, and `knowledge_uncertainty`. Without these stochastic samples $\hat{p}_c^t$ from dropout, we could not calculate these different uncertainty types for active learning sample selection.

# %%
def get_mc_predictions(model: nn.Module, n_iter: int, x_train: torch.Tensor) -> torch.Tensor:
    device = next(model.parameters()).device
    preds = []
    # Set model to training mode to enable dropout
    model.train()
    with torch.no_grad():
        for _ in tqdm(range(n_iter)):
            # Split data into batches
            preds_iter = []
            for batch in torch.chunk(x_train, chunks=6):
                batch = batch.to(device)
                # Ensure input is float and has correct shape (add channel dim if needed)
                if len(batch.shape) == 3:
                    batch = batch.unsqueeze(1)
                preds_iter.append(model(batch))
            # Concatenate batch predictions
            preds.append(torch.cat(preds_iter, dim=0))
    # Stack predictions and move axes to get (n_images, n_predictions, n_classes)
    preds = torch.stack(preds, dim=1)
    return preds

# %% [markdown]
# **Question 4 (10 marks)**
#
# Write the code for the functions `data_uncertainty` and `total_uncertainty` below

# %% [markdown]
# *Solution*
#
# We give 5 marks for a correct version of each function.

# %%
def total_uncertainty(preds: torch.Tensor, epsilon: float = 1e-10) -> torch.Tensor:
    # Calculate mean prediction across all MC samples for each image
    mean_preds = torch.mean(preds, dim=1)
    # Calculate entropy of the mean prediction (total uncertainty)
    return -torch.sum(mean_preds * torch.log(mean_preds + epsilon), dim=1)

def data_uncertainty(preds: torch.Tensor, epsilon: float = 1e-10) -> torch.Tensor:
    # Calculate entropy for each MC prediction
    entropies = -torch.sum(preds * torch.log(preds + epsilon), dim=2)
    # Average entropy across MC samples (data/aleatoric uncertainty)
    return torch.mean(entropies, dim=1)

def knowledge_uncertainty(preds: torch.Tensor, epsilon: float = 1e-10) -> torch.Tensor:
    # Knowledge uncertainty is the difference between total and data uncertainty
    return total_uncertainty(preds, epsilon) - data_uncertainty(preds, epsilon)

# %% [markdown]
# The acquisition function that uses the knowledge uncertainty function can be summarised in three steps
# 1. Obtain an ensemble of predictions via MC dropout (done by `get_mc_predictions`).
# 2. Compute the knowledge uncertainty values over this prediction
# ensemble (use `knowledge_uncertainty` function).
# 3. Sort the uncertainty values, get their index and return the
# indices of the data in the pool with the highest epistemic
# uncertainty.

# %%
def acquire_knowledge_uncertainty(
    x_train: torch.Tensor, n_samples: int, model: nn.Module, n_iter: int, *args, **kwargs
):
    # Get Monte Carlo predictions
    preds = get_mc_predictions(model, n_iter, x_train)
    # Compute knowledge uncertainty
    ku = knowledge_uncertainty(preds)
    # Get indices of samples with highest uncertainty
    _, indices = torch.topk(ku, n_samples)
    return indices.cpu().numpy()

# %% [markdown]
# ### 2.3.2 Laplace uncertainty
#
# Rather than using MC dropout to compute samples on the parameters of the neural network, we can use a Laplace approximation, which approximates the posterior distribution of the parameters using a Gaussian distribution.
#
# The predictive distribution under a Bayesian approach (Gal, 2016) can be written as:
#
# $$p(y=c|x, D_{train}) = \int p(y=c|x, \omega)p(\omega|D_{train})d\omega.$$
#
# With Laplace approximation, we approximate the posterior $p(\omega|D_{train})$ with a **Gaussian distribution** $N$ centered at the MAP estimate:
#
# $$p(\omega|D_{train}) \approx N(\omega|\omega_{MAP}, \Sigma_{post}),$$
#
# where:
# - $\omega_{MAP}$ is the maximum a posteriori estimate of the parameters
# - $\Sigma_{post}$ is the covariance matrix computed at $\omega_{MAP}$.
#
# We can then use this posterior distribution and the probit likelihood to approximate the posterior probabilities over the classes.
#
# Computing the Laplace approximation for a posterior distribution of a neural network is cumbersome in general. Here, we use a recent package known as [Laplace that allows to compute the posterior distribution effortlessly](https://github.com/AlexImmer/Laplace).
#
# ### Uncertainty Measure for Acquisition when using the Laplace approximation
#
# We use Max Entropy (Shannon, 1948) as an uncertainty measure in this case:
#
# $$H[y|x, D_{train}] := -\sum_{c} p(y=c|x, D_{train}) \log p(y=c|x, D_{train})$$
#
# This acquisition function selects pool points that maximize the predictive entropy.
#
# The acquisition function that uses the max entropy with Laplace approximation can be summarised in three steps
# 1. Obtain the predictions under the posterior distribution via Laplace approximation.
# 2. Compute the max entropy values for the datapoints in the pool.
# 3. Sort the uncertainty values, get their index and return the
# indices of the data in the pool with the highest epistemic
# uncertainty.

# %% [markdown]
# **Question 5 (10 marks)**
#
# The following acquisition function implements the three steps above. Write the code for steps 1 and 2.

# %% [markdown]
# *Solution*
#
# 5 marks for each step

# %%
def acquire_laplace_uncertainty(
    unlabeled_tensor: torch.Tensor, n_samples: int, la_model: Laplace) -> np.ndarray:
    try:
        # Step 1: Predict probabilities with error handling
        preds = la_model(unlabeled_tensor, pred_type='glm', link_approx='probit')
        # Convert to numpy with checks
        try:
            preds_np = preds.numpy()
        except Exception:
            preds_np = preds.detach().cpu().numpy()

        # Step 2: Entropy calculation
        epsilon = 1e-10
        uncertainty = -np.sum(preds_np * np.log(preds_np + epsilon), axis=1)

        # Step 3: Select indices with highest uncertainty
        indices = np.argsort(uncertainty)[-n_samples:]
        return indices

    except Exception as e:
        print(f"Laplace Acquisition Error: {e}")
        # Fallback to random sampling
        return np.random.choice(len(unlabeled_tensor), n_samples, replace=False)

# %% [markdown]
# ### 2.3.3 Random selection
#
# The simplest approach to select a datapoint from the pool is to do it randomly

# %%
def acquire_random(x_train: torch.Tensor, n_samples: int, *args, **kwargs) -> np.ndarray:
    # Randomly select samples
    return torch.randperm(len(x_train))[:n_samples].numpy()

# %% [markdown]
# ### 2.3.4 A battery of acquisition functions
#
# We can group the three acquisition functions above in a function,

# %%
def acquisition_factory(acquisition_type: str) -> Callable:
    if acquisition_type == "laplace_uncertainty":
        return acquire_laplace_uncertainty
    if acquisition_type == "knowledge_uncertainty":
        return acquire_knowledge_uncertainty
    elif acquisition_type == "random":
        return acquire_random
    else:
        raise ValueError(f"Acquisition type {acquisition_type} not supported")

# %% [markdown]
# Now that we have defined our acquisition functions, we are ready
# to define the loop that runs the active learning iterations.

# %% [markdown]
# ## 2.4 Main Loop for Active Learning
#
# We will start our dataset with 20 samples until we reach a total of 500 samples. Each model will be trained for 25 epochs and per iteration, we acquire 10 samples. To obtain our MC dropout predictions, we will run over
# our full training set (minus the already acquired samples) 48 times.
#
# It will take you approx. 1 hour to finish the active learning loop using standard colab T4 GPU.

# %%
import main
main.acquisition_factory= acquisition_factory #Put your acquisition functions inside the main module
from main import Active_learning

# %%
# Run Active Learning on Laplace Uncertainty Acquisition
accuracies_l, added_indices_l = Active_learning(
    acquisition_type="laplace_uncertainty",
    n_epochs=50,
    n_samples_per_iter=10,
    initial_n_samples=20,
    n_total_samples=500,
    use_wandb=False
)

# Run Active Learning on Random Acquisition
accuracies_r, added_indices_r = Active_learning(
    acquisition_type="random",
    n_epochs=50,
    n_samples_per_iter=10,
    initial_n_samples=20,
    n_total_samples=500,
    use_wandb=False
)

# Run Active Learning on Knowlege Uncertainty Acquisition
accuracies_k, added_indices_k = Active_learning(
   acquisition_type="knowledge_uncertainty",
    n_epochs=50,
    n_samples_per_iter=10,
    initial_n_samples=20,
    n_total_samples=500,
    use_wandb=False
)
# Out:
# Using device: cuda
# Model directory: models/laplace_uncertainty/fb390fcb-50c9-491d-94a6-41509d944309
# Laplace_Uncertainty Iteration 1/48
# Epoch 1/50 - Loss: 2.3140 - Acc: 0.1000 - Val Loss: 2.2909 - Val Acc: 0.2015
# Epoch 25/50 - Loss: 0.0557 - Acc: 1.0000 - Val Loss: 1.3185 - Val Acc: 0.6244
# Epoch 50/50 - Loss: 0.0022 - Acc: 1.0000 - Val Loss: 1.7231 - Val Acc: 0.6463
# Laplace approximation fitted
# Iteration 1: Added 10 samples - Accuracy: 64.63%
# Laplace_Uncertainty Iteration 2/48
# Epoch 1/50 - Loss: 2.3026 - Acc: 0.1667 - Val Loss: 2.2912 - Val Acc: 0.2017
# Epoch 25/50 - Loss: 0.1876 - Acc: 0.9333 - Val Loss: 1.2346 - Val Acc: 0.6460
# Epoch 50/50 - Loss: 0.0035 - Acc: 1.0000 - Val Loss: 1.5155 - Val Acc: 0.6738
# Laplace approximation fitted
# Iteration 2: Added 10 samples - Accuracy: 67.38%
# Laplace_Uncertainty Iteration 3/48
# Epoch 1/50 - Loss: 2.3203 - Acc: 0.1250 - Val Loss: 2.2957 - Val Acc: 0.1185
# Epoch 25/50 - Loss: 0.2882 - Acc: 0.9250 - Val Loss: 1.2094 - Val Acc: 0.6286
# Epoch 50/50 - Loss: 0.0559 - Acc: 0.9750 - Val Loss: 1.3591 - Val Acc: 0.6839
# Laplace approximation fitted
# Iteration 3: Added 10 samples - Accuracy: 68.39%
# Laplace_Uncertainty Iteration 4/48
# Epoch 1/50 - Loss: 2.3209 - Acc: 0.1400 - Val Loss: 2.2859 - Val Acc: 0.0982
# Epoch 25/50 - Loss: 0.1446 - Acc: 1.0000 - Val Loss: 1.0724 - Val Acc: 0.6920
# Epoch 50/50 - Loss: 0.0389 - Acc: 0.9800 - Val Loss: 1.4743 - Val Acc: 0.6953
# Laplace approximation fitted
# Iteration 4: Added 10 samples - Accuracy: 69.53%
# Laplace_Uncertainty Iteration 5/48
# Epoch 1/50 - Loss: 2.3098 - Acc: 0.0667 - Val Loss: 2.2999 - Val Acc: 0.1328
# Epoch 25/50 - Loss: 0.1912 - Acc: 0.9500 - Val Loss: 1.1658 - Val Acc: 0.6876
# Epoch 50/50 - Loss: 0.0077 - Acc: 1.0000 - Val Loss: 1.3460 - Val Acc: 0.7156
# Laplace approximation fitted
# Iteration 5: Added 10 samples - Accuracy: 71.56%
# Laplace_Uncertainty Iteration 6/48
# Epoch 1/50 - Loss: 2.2925 - Acc: 0.1429 - Val Loss: 2.2946 - Val Acc: 0.1281
# Epoch 25/50 - Loss: 0.4184 - Acc: 0.8429 - Val Loss: 1.0974 - Val Acc: 0.6902
# Epoch 50/50 - Loss: 0.0749 - Acc: 0.9857 - Val Loss: 1.1622 - Val Acc: 0.7252
# Laplace approximation fitted
# Iteration 6: Added 10 samples - Accuracy: 72.52%
# Laplace_Uncertainty Iteration 7/48
# Epoch 1/50 - Loss: 2.3122 - Acc: 0.0500 - Val Loss: 2.3027 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1043 - Acc: 0.9625 - Val Loss: 0.9771 - Val Acc: 0.7365
# Epoch 50/50 - Loss: 0.0284 - Acc: 1.0000 - Val Loss: 1.1566 - Val Acc: 0.7452
# Laplace approximation fitted
# Iteration 7: Added 10 samples - Accuracy: 74.52%
# Laplace_Uncertainty Iteration 8/48
# Epoch 1/50 - Loss: 2.3046 - Acc: 0.1111 - Val Loss: 2.2714 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1800 - Acc: 0.9444 - Val Loss: 0.9973 - Val Acc: 0.7349
# Epoch 50/50 - Loss: 0.0898 - Acc: 0.9667 - Val Loss: 1.3267 - Val Acc: 0.7280
# Laplace approximation fitted
# Iteration 8: Added 10 samples - Accuracy: 72.80%
# Laplace_Uncertainty Iteration 9/48
# Epoch 1/50 - Loss: 2.2979 - Acc: 0.1400 - Val Loss: 2.2988 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.3307 - Acc: 0.8900 - Val Loss: 1.0297 - Val Acc: 0.6824
# Epoch 50/50 - Loss: 0.0720 - Acc: 0.9900 - Val Loss: 0.8782 - Val Acc: 0.7689
# Laplace approximation fitted
# Iteration 9: Added 10 samples - Accuracy: 76.89%
# Laplace_Uncertainty Iteration 10/48
# Epoch 1/50 - Loss: 2.2937 - Acc: 0.1545 - Val Loss: 2.2803 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.2061 - Acc: 0.9273 - Val Loss: 0.7615 - Val Acc: 0.7978
# Epoch 50/50 - Loss: 0.0612 - Acc: 0.9818 - Val Loss: 0.8092 - Val Acc: 0.8185
# Laplace approximation fitted
# Iteration 10: Added 10 samples - Accuracy: 81.85%
# Laplace_Uncertainty Iteration 11/48
# Epoch 1/50 - Loss: 2.3149 - Acc: 0.1083 - Val Loss: 2.2687 - Val Acc: 0.1493
# Epoch 25/50 - Loss: 0.2135 - Acc: 0.9250 - Val Loss: 0.6182 - Val Acc: 0.8343
# Epoch 50/50 - Loss: 0.0830 - Acc: 0.9833 - Val Loss: 0.8125 - Val Acc: 0.8228
# Laplace approximation fitted
# Iteration 11: Added 10 samples - Accuracy: 82.28%
# Laplace_Uncertainty Iteration 12/48
# Epoch 1/50 - Loss: 2.3153 - Acc: 0.1077 - Val Loss: 2.2733 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.3434 - Acc: 0.9000 - Val Loss: 0.5291 - Val Acc: 0.8324
# Epoch 50/50 - Loss: 0.0711 - Acc: 0.9769 - Val Loss: 0.5983 - Val Acc: 0.8553
# Laplace approximation fitted
# Iteration 12: Added 10 samples - Accuracy: 85.53%
# Laplace_Uncertainty Iteration 13/48
# Epoch 1/50 - Loss: 2.3047 - Acc: 0.1000 - Val Loss: 2.2566 - Val Acc: 0.1048
# Epoch 25/50 - Loss: 0.1369 - Acc: 0.9643 - Val Loss: 0.5249 - Val Acc: 0.8486
# Epoch 50/50 - Loss: 0.0477 - Acc: 0.9857 - Val Loss: 0.5978 - Val Acc: 0.8572
# Laplace approximation fitted
# Iteration 13: Added 10 samples - Accuracy: 85.72%
# Laplace_Uncertainty Iteration 14/48
# Epoch 1/50 - Loss: 2.2806 - Acc: 0.1533 - Val Loss: 2.2751 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.2041 - Acc: 0.9333 - Val Loss: 0.5515 - Val Acc: 0.8421
# Epoch 50/50 - Loss: 0.0521 - Acc: 0.9800 - Val Loss: 0.4968 - Val Acc: 0.8813
# Laplace approximation fitted
# Iteration 14: Added 10 samples - Accuracy: 88.13%
# Laplace_Uncertainty Iteration 15/48
# Epoch 1/50 - Loss: 2.3017 - Acc: 0.1250 - Val Loss: 2.2701 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1195 - Acc: 0.9625 - Val Loss: 0.4597 - Val Acc: 0.8705
# Epoch 50/50 - Loss: 0.0812 - Acc: 0.9750 - Val Loss: 0.5386 - Val Acc: 0.8723
# Laplace approximation fitted
# Iteration 15: Added 10 samples - Accuracy: 87.23%
# Laplace_Uncertainty Iteration 16/48
# Epoch 1/50 - Loss: 2.3149 - Acc: 0.1176 - Val Loss: 2.2592 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1225 - Acc: 0.9647 - Val Loss: 0.4459 - Val Acc: 0.8718
# Epoch 50/50 - Loss: 0.0663 - Acc: 0.9824 - Val Loss: 0.4522 - Val Acc: 0.8820
# Laplace approximation fitted
# Iteration 16: Added 10 samples - Accuracy: 88.20%
# Laplace_Uncertainty Iteration 17/48
# Epoch 1/50 - Loss: 2.3111 - Acc: 0.1000 - Val Loss: 2.2611 - Val Acc: 0.1052
# Epoch 25/50 - Loss: 0.1185 - Acc: 0.9667 - Val Loss: 0.4334 - Val Acc: 0.8801
# Epoch 50/50 - Loss: 0.0245 - Acc: 0.9944 - Val Loss: 0.4388 - Val Acc: 0.8926
# Laplace approximation fitted
# Iteration 17: Added 10 samples - Accuracy: 89.26%
# Laplace_Uncertainty Iteration 18/48
# Epoch 1/50 - Loss: 2.3105 - Acc: 0.1000 - Val Loss: 2.2422 - Val Acc: 0.1142
# Epoch 25/50 - Loss: 0.1339 - Acc: 0.9579 - Val Loss: 0.3868 - Val Acc: 0.8955
# Epoch 50/50 - Loss: 0.0527 - Acc: 0.9895 - Val Loss: 0.3715 - Val Acc: 0.9002
# Laplace approximation fitted
# Iteration 18: Added 10 samples - Accuracy: 90.02%
# Laplace_Uncertainty Iteration 19/48
# Epoch 1/50 - Loss: 2.2967 - Acc: 0.1100 - Val Loss: 2.1975 - Val Acc: 0.2029
# Epoch 25/50 - Loss: 0.1829 - Acc: 0.9500 - Val Loss: 0.3198 - Val Acc: 0.9058
# Epoch 50/50 - Loss: 0.0588 - Acc: 0.9750 - Val Loss: 0.3232 - Val Acc: 0.9115
# Laplace approximation fitted
# Iteration 19: Added 10 samples - Accuracy: 91.15%
# Laplace_Uncertainty Iteration 20/48
# Epoch 1/50 - Loss: 2.2995 - Acc: 0.1190 - Val Loss: 2.2249 - Val Acc: 0.1721
# Epoch 25/50 - Loss: 0.1611 - Acc: 0.9524 - Val Loss: 0.2877 - Val Acc: 0.9140
# Epoch 50/50 - Loss: 0.0576 - Acc: 0.9905 - Val Loss: 0.2878 - Val Acc: 0.9261
# Laplace approximation fitted
# Iteration 20: Added 10 samples - Accuracy: 92.61%
# Laplace_Uncertainty Iteration 21/48
# Epoch 1/50 - Loss: 2.2952 - Acc: 0.1182 - Val Loss: 2.2503 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.2345 - Acc: 0.9227 - Val Loss: 0.3293 - Val Acc: 0.9078
# Epoch 50/50 - Loss: 0.0833 - Acc: 0.9773 - Val Loss: 0.3842 - Val Acc: 0.9113
# Laplace approximation fitted
# Iteration 21: Added 10 samples - Accuracy: 91.13%
# Laplace_Uncertainty Iteration 22/48
# Epoch 1/50 - Loss: 2.2880 - Acc: 0.1391 - Val Loss: 2.2061 - Val Acc: 0.2436
# Epoch 25/50 - Loss: 0.1378 - Acc: 0.9652 - Val Loss: 0.2950 - Val Acc: 0.9204
# Epoch 50/50 - Loss: 0.0284 - Acc: 0.9870 - Val Loss: 0.2785 - Val Acc: 0.9321
# Laplace approximation fitted
# Iteration 22: Added 10 samples - Accuracy: 93.21%
# Laplace_Uncertainty Iteration 23/48
# Epoch 1/50 - Loss: 2.2738 - Acc: 0.1333 - Val Loss: 2.1877 - Val Acc: 0.2145
# Epoch 25/50 - Loss: 0.1246 - Acc: 0.9583 - Val Loss: 0.3105 - Val Acc: 0.9095
# Epoch 50/50 - Loss: 0.0647 - Acc: 0.9792 - Val Loss: 0.3683 - Val Acc: 0.9092
# Laplace approximation fitted
# Iteration 23: Added 10 samples - Accuracy: 90.92%
# Laplace_Uncertainty Iteration 24/48
# Epoch 1/50 - Loss: 2.2831 - Acc: 0.1520 - Val Loss: 2.1954 - Val Acc: 0.1418
# Epoch 25/50 - Loss: 0.1065 - Acc: 0.9800 - Val Loss: 0.3117 - Val Acc: 0.9085
# Epoch 50/50 - Loss: 0.0378 - Acc: 0.9960 - Val Loss: 0.3111 - Val Acc: 0.9255
# Laplace approximation fitted
# Iteration 24: Added 10 samples - Accuracy: 92.55%
# Laplace_Uncertainty Iteration 25/48
# Epoch 1/50 - Loss: 2.2771 - Acc: 0.1346 - Val Loss: 2.2787 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1542 - Acc: 0.9385 - Val Loss: 0.2762 - Val Acc: 0.9186
# Epoch 50/50 - Loss: 0.0627 - Acc: 0.9808 - Val Loss: 0.3391 - Val Acc: 0.9239
# Laplace approximation fitted
# Iteration 25: Added 10 samples - Accuracy: 92.39%
# Laplace_Uncertainty Iteration 26/48
# Epoch 1/50 - Loss: 2.2749 - Acc: 0.1370 - Val Loss: 2.1862 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1330 - Acc: 0.9667 - Val Loss: 0.2414 - Val Acc: 0.9325
# Epoch 50/50 - Loss: 0.0333 - Acc: 0.9889 - Val Loss: 0.2361 - Val Acc: 0.9402
# Laplace approximation fitted
# Iteration 26: Added 10 samples - Accuracy: 94.02%
# Laplace_Uncertainty Iteration 27/48
# Epoch 1/50 - Loss: 2.2581 - Acc: 0.1679 - Val Loss: 2.2232 - Val Acc: 0.1032
# Epoch 25/50 - Loss: 0.1073 - Acc: 0.9750 - Val Loss: 0.2548 - Val Acc: 0.9268
# Epoch 50/50 - Loss: 0.0406 - Acc: 0.9929 - Val Loss: 0.3124 - Val Acc: 0.9252
# Laplace approximation fitted
# Iteration 27: Added 10 samples - Accuracy: 92.52%
# Laplace_Uncertainty Iteration 28/48
# Epoch 1/50 - Loss: 2.2938 - Acc: 0.1034 - Val Loss: 2.2235 - Val Acc: 0.2173
# Epoch 25/50 - Loss: 0.2150 - Acc: 0.9276 - Val Loss: 0.2232 - Val Acc: 0.9344
# Epoch 50/50 - Loss: 0.0527 - Acc: 0.9828 - Val Loss: 0.2623 - Val Acc: 0.9319
# Laplace approximation fitted
# Iteration 28: Added 10 samples - Accuracy: 93.19%
# Laplace_Uncertainty Iteration 29/48
# Epoch 1/50 - Loss: 2.2316 - Acc: 0.1833 - Val Loss: 2.1234 - Val Acc: 0.1196
# Epoch 25/50 - Loss: 0.1093 - Acc: 0.9567 - Val Loss: 0.2743 - Val Acc: 0.9262
# Epoch 50/50 - Loss: 0.0714 - Acc: 0.9767 - Val Loss: 0.2958 - Val Acc: 0.9346
# Laplace approximation fitted
# Iteration 29: Added 10 samples - Accuracy: 93.46%
# Laplace_Uncertainty Iteration 30/48
# Epoch 1/50 - Loss: 2.2754 - Acc: 0.1387 - Val Loss: 2.1597 - Val Acc: 0.2783
# Epoch 25/50 - Loss: 0.1126 - Acc: 0.9710 - Val Loss: 0.2288 - Val Acc: 0.9353
# Epoch 50/50 - Loss: 0.0630 - Acc: 0.9710 - Val Loss: 0.2948 - Val Acc: 0.9301
# Laplace approximation fitted
# Iteration 30: Added 10 samples - Accuracy: 93.01%
# Laplace_Uncertainty Iteration 31/48
# Epoch 1/50 - Loss: 2.2907 - Acc: 0.1656 - Val Loss: 2.2226 - Val Acc: 0.2264
# Epoch 25/50 - Loss: 0.1335 - Acc: 0.9594 - Val Loss: 0.2216 - Val Acc: 0.9350
# Epoch 50/50 - Loss: 0.0386 - Acc: 0.9875 - Val Loss: 0.2762 - Val Acc: 0.9407
# Laplace approximation fitted
# Iteration 31: Added 10 samples - Accuracy: 94.07%
# Laplace_Uncertainty Iteration 32/48
# Epoch 1/50 - Loss: 2.2508 - Acc: 0.1939 - Val Loss: 2.1806 - Val Acc: 0.1897
# Epoch 25/50 - Loss: 0.1345 - Acc: 0.9636 - Val Loss: 0.2245 - Val Acc: 0.9378
# Epoch 50/50 - Loss: 0.0654 - Acc: 0.9758 - Val Loss: 0.2746 - Val Acc: 0.9356
# Laplace approximation fitted
# Iteration 32: Added 10 samples - Accuracy: 93.56%
# Laplace_Uncertainty Iteration 33/48
# Epoch 1/50 - Loss: 2.2346 - Acc: 0.1706 - Val Loss: 2.1068 - Val Acc: 0.1901
# Epoch 25/50 - Loss: 0.0716 - Acc: 0.9735 - Val Loss: 0.2274 - Val Acc: 0.9350
# Epoch 50/50 - Loss: 0.0222 - Acc: 0.9912 - Val Loss: 0.2631 - Val Acc: 0.9346
# Laplace approximation fitted
# Iteration 33: Added 10 samples - Accuracy: 93.46%
# Laplace_Uncertainty Iteration 34/48
# Epoch 1/50 - Loss: 2.2613 - Acc: 0.1457 - Val Loss: 2.1327 - Val Acc: 0.2283
# Epoch 25/50 - Loss: 0.1195 - Acc: 0.9600 - Val Loss: 0.2023 - Val Acc: 0.9434
# Epoch 50/50 - Loss: 0.0544 - Acc: 0.9800 - Val Loss: 0.2386 - Val Acc: 0.9467
# Laplace approximation fitted
# Iteration 34: Added 10 samples - Accuracy: 94.67%
# Laplace_Uncertainty Iteration 35/48
# Epoch 1/50 - Loss: 2.2193 - Acc: 0.1972 - Val Loss: 2.0636 - Val Acc: 0.2889
# Epoch 25/50 - Loss: 0.1382 - Acc: 0.9500 - Val Loss: 0.2114 - Val Acc: 0.9412
# Epoch 50/50 - Loss: 0.0695 - Acc: 0.9694 - Val Loss: 0.2465 - Val Acc: 0.9344
# Laplace approximation fitted
# Iteration 35: Added 10 samples - Accuracy: 93.44%
# Laplace_Uncertainty Iteration 36/48
# Epoch 1/50 - Loss: 2.2162 - Acc: 0.2000 - Val Loss: 2.0129 - Val Acc: 0.2865
# Epoch 25/50 - Loss: 0.1337 - Acc: 0.9568 - Val Loss: 0.2259 - Val Acc: 0.9339
# Epoch 50/50 - Loss: 0.0566 - Acc: 0.9838 - Val Loss: 0.2298 - Val Acc: 0.9451
# Laplace approximation fitted
# Iteration 36: Added 10 samples - Accuracy: 94.51%
# Laplace_Uncertainty Iteration 37/48
# Epoch 1/50 - Loss: 2.2770 - Acc: 0.1658 - Val Loss: 2.1823 - Val Acc: 0.1061
# Epoch 25/50 - Loss: 0.0972 - Acc: 0.9579 - Val Loss: 0.1919 - Val Acc: 0.9465
# Epoch 50/50 - Loss: 0.0548 - Acc: 0.9789 - Val Loss: 0.2109 - Val Acc: 0.9444
# Laplace approximation fitted
# Iteration 37: Added 10 samples - Accuracy: 94.44%
# Laplace_Uncertainty Iteration 38/48
# Epoch 1/50 - Loss: 2.2533 - Acc: 0.1462 - Val Loss: 2.1416 - Val Acc: 0.1619
# Epoch 25/50 - Loss: 0.1108 - Acc: 0.9718 - Val Loss: 0.1920 - Val Acc: 0.9436
# Epoch 50/50 - Loss: 0.0381 - Acc: 0.9821 - Val Loss: 0.1998 - Val Acc: 0.9515
# Laplace approximation fitted
# Iteration 38: Added 10 samples - Accuracy: 95.15%
# Laplace_Uncertainty Iteration 39/48
# Epoch 1/50 - Loss: 2.2715 - Acc: 0.1350 - Val Loss: 2.1650 - Val Acc: 0.1815
# Epoch 25/50 - Loss: 0.1052 - Acc: 0.9625 - Val Loss: 0.1802 - Val Acc: 0.9495
# Epoch 50/50 - Loss: 0.0459 - Acc: 0.9900 - Val Loss: 0.2448 - Val Acc: 0.9476
# Laplace approximation fitted
# Iteration 39: Added 10 samples - Accuracy: 94.76%
# Laplace_Uncertainty Iteration 40/48
# Epoch 1/50 - Loss: 2.2202 - Acc: 0.2195 - Val Loss: 1.9828 - Val Acc: 0.3040
# Epoch 25/50 - Loss: 0.1265 - Acc: 0.9537 - Val Loss: 0.2072 - Val Acc: 0.9447
# Epoch 50/50 - Loss: 0.0709 - Acc: 0.9732 - Val Loss: 0.2347 - Val Acc: 0.9495
# Laplace approximation fitted
# Iteration 40: Added 10 samples - Accuracy: 94.95%
# Laplace_Uncertainty Iteration 41/48
# Epoch 1/50 - Loss: 2.2211 - Acc: 0.1500 - Val Loss: 2.0246 - Val Acc: 0.2787
# Epoch 25/50 - Loss: 0.1480 - Acc: 0.9476 - Val Loss: 0.1818 - Val Acc: 0.9503
# Epoch 50/50 - Loss: 0.0840 - Acc: 0.9762 - Val Loss: 0.2051 - Val Acc: 0.9499
# Laplace approximation fitted
# Iteration 41: Added 10 samples - Accuracy: 94.99%
# Laplace_Uncertainty Iteration 42/48
# Epoch 1/50 - Loss: 2.2304 - Acc: 0.1791 - Val Loss: 1.9882 - Val Acc: 0.3333
# Epoch 25/50 - Loss: 0.0875 - Acc: 0.9721 - Val Loss: 0.1814 - Val Acc: 0.9505
# Epoch 50/50 - Loss: 0.0374 - Acc: 0.9907 - Val Loss: 0.2220 - Val Acc: 0.9517
# Laplace approximation fitted
# Iteration 42: Added 10 samples - Accuracy: 95.17%
# Laplace_Uncertainty Iteration 43/48
# Epoch 1/50 - Loss: 2.2023 - Acc: 0.1841 - Val Loss: 1.9557 - Val Acc: 0.4095
# Epoch 25/50 - Loss: 0.1013 - Acc: 0.9636 - Val Loss: 0.1937 - Val Acc: 0.9430
# Epoch 50/50 - Loss: 0.0425 - Acc: 0.9841 - Val Loss: 0.2064 - Val Acc: 0.9517
# Laplace approximation fitted
# Iteration 43: Added 10 samples - Accuracy: 95.17%
# Laplace_Uncertainty Iteration 44/48
# Epoch 1/50 - Loss: 2.2140 - Acc: 0.1933 - Val Loss: 1.9482 - Val Acc: 0.5271
# Epoch 25/50 - Loss: 0.0992 - Acc: 0.9667 - Val Loss: 0.1589 - Val Acc: 0.9533
# Epoch 50/50 - Loss: 0.0371 - Acc: 0.9867 - Val Loss: 0.1738 - Val Acc: 0.9561
# Laplace approximation fitted
# Iteration 44: Added 10 samples - Accuracy: 95.61%
# Laplace_Uncertainty Iteration 45/48
# Epoch 1/50 - Loss: 2.1952 - Acc: 0.1804 - Val Loss: 1.9504 - Val Acc: 0.3091
# Epoch 25/50 - Loss: 0.1048 - Acc: 0.9696 - Val Loss: 0.1773 - Val Acc: 0.9489
# Epoch 50/50 - Loss: 0.0469 - Acc: 0.9891 - Val Loss: 0.1951 - Val Acc: 0.9548
# Laplace approximation fitted
# Iteration 45: Added 10 samples - Accuracy: 95.48%
# Laplace_Uncertainty Iteration 46/48
# Epoch 1/50 - Loss: 2.2800 - Acc: 0.1447 - Val Loss: 2.1531 - Val Acc: 0.2165
# Epoch 25/50 - Loss: 0.1479 - Acc: 0.9468 - Val Loss: 0.1809 - Val Acc: 0.9517
# Epoch 50/50 - Loss: 0.0758 - Acc: 0.9617 - Val Loss: 0.2383 - Val Acc: 0.9473
# Laplace approximation fitted
# Iteration 46: Added 10 samples - Accuracy: 94.73%
# Laplace_Uncertainty Iteration 47/48
# Epoch 1/50 - Loss: 2.2190 - Acc: 0.1958 - Val Loss: 1.9754 - Val Acc: 0.2341
# Epoch 25/50 - Loss: 0.0914 - Acc: 0.9708 - Val Loss: 0.1725 - Val Acc: 0.9520
# Epoch 50/50 - Loss: 0.0558 - Acc: 0.9833 - Val Loss: 0.2104 - Val Acc: 0.9521
# Laplace approximation fitted
# Iteration 47: Added 10 samples - Accuracy: 95.21%
# Laplace_Uncertainty Iteration 48/48
# Epoch 1/50 - Loss: 2.2477 - Acc: 0.1857 - Val Loss: 2.0301 - Val Acc: 0.2577
# Epoch 25/50 - Loss: 0.1705 - Acc: 0.9367 - Val Loss: 0.1746 - Val Acc: 0.9488
# Epoch 50/50 - Loss: 0.0511 - Acc: 0.9816 - Val Loss: 0.1946 - Val Acc: 0.9543
# Laplace approximation fitted
# Iteration 48: Added 10 samples - Accuracy: 95.43%
#
# ===== Completed laplace_uncertainty acquisition =====
#
# Using device: cuda
# Model directory: models/random/205986fe-75d7-4816-99ae-b18627fb7ce9
# Random Iteration 1/48
# Epoch 1/50 - Loss: 2.3183 - Acc: 0.1000 - Val Loss: 2.3012 - Val Acc: 0.1688
# Epoch 25/50 - Loss: 0.3202 - Acc: 0.9500 - Val Loss: 1.3971 - Val Acc: 0.5534
# Epoch 50/50 - Loss: 0.0112 - Acc: 1.0000 - Val Loss: 2.1933 - Val Acc: 0.5572
# Iteration 1: Added 10 samples - Accuracy: 55.72%
# Random Iteration 2/48
# Epoch 1/50 - Loss: 2.2915 - Acc: 0.1667 - Val Loss: 2.2897 - Val Acc: 0.1528
# Epoch 25/50 - Loss: 0.1017 - Acc: 1.0000 - Val Loss: 1.2227 - Val Acc: 0.6422
# Epoch 50/50 - Loss: 0.0387 - Acc: 1.0000 - Val Loss: 1.6129 - Val Acc: 0.6501
# Iteration 2: Added 10 samples - Accuracy: 65.01%
# Random Iteration 3/48
# Epoch 1/50 - Loss: 2.3011 - Acc: 0.0750 - Val Loss: 2.2843 - Val Acc: 0.0993
# Epoch 25/50 - Loss: 0.1844 - Acc: 0.9250 - Val Loss: 1.2106 - Val Acc: 0.6570
# Epoch 50/50 - Loss: 0.0095 - Acc: 1.0000 - Val Loss: 1.4915 - Val Acc: 0.6900
# Iteration 3: Added 10 samples - Accuracy: 69.00%
# Random Iteration 4/48
# Epoch 1/50 - Loss: 2.3151 - Acc: 0.1000 - Val Loss: 2.2826 - Val Acc: 0.1261
# Epoch 25/50 - Loss: 0.1602 - Acc: 0.9600 - Val Loss: 0.9771 - Val Acc: 0.7265
# Epoch 50/50 - Loss: 0.0238 - Acc: 1.0000 - Val Loss: 1.4431 - Val Acc: 0.7007
# Iteration 4: Added 10 samples - Accuracy: 70.07%
# Random Iteration 5/48
# Epoch 1/50 - Loss: 2.3158 - Acc: 0.0500 - Val Loss: 2.2804 - Val Acc: 0.2226
# Epoch 25/50 - Loss: 0.1545 - Acc: 0.9333 - Val Loss: 0.9291 - Val Acc: 0.7650
# Epoch 50/50 - Loss: 0.0369 - Acc: 1.0000 - Val Loss: 1.1095 - Val Acc: 0.7595
# Iteration 5: Added 10 samples - Accuracy: 75.95%
# Random Iteration 6/48
# Epoch 1/50 - Loss: 2.3007 - Acc: 0.1000 - Val Loss: 2.2716 - Val Acc: 0.1296
# Epoch 25/50 - Loss: 0.0588 - Acc: 1.0000 - Val Loss: 0.8975 - Val Acc: 0.7646
# Epoch 50/50 - Loss: 0.0540 - Acc: 0.9857 - Val Loss: 1.0511 - Val Acc: 0.7705
# Iteration 6: Added 10 samples - Accuracy: 77.05%
# Random Iteration 7/48
# Epoch 1/50 - Loss: 2.3188 - Acc: 0.1000 - Val Loss: 2.2683 - Val Acc: 0.2405
# Epoch 25/50 - Loss: 0.1063 - Acc: 0.9625 - Val Loss: 0.8307 - Val Acc: 0.7918
# Epoch 50/50 - Loss: 0.0217 - Acc: 1.0000 - Val Loss: 1.0216 - Val Acc: 0.7931
# Iteration 7: Added 10 samples - Accuracy: 79.31%
# Random Iteration 8/48
# Epoch 1/50 - Loss: 2.3186 - Acc: 0.0778 - Val Loss: 2.2731 - Val Acc: 0.1009
# Epoch 25/50 - Loss: 0.0626 - Acc: 0.9889 - Val Loss: 0.8094 - Val Acc: 0.7896
# Epoch 50/50 - Loss: 0.0865 - Acc: 0.9778 - Val Loss: 0.9416 - Val Acc: 0.7909
# Iteration 8: Added 10 samples - Accuracy: 79.09%
# Random Iteration 9/48
# Epoch 1/50 - Loss: 2.2812 - Acc: 0.1600 - Val Loss: 2.2944 - Val Acc: 0.1010
# Epoch 25/50 - Loss: 0.2347 - Acc: 0.9400 - Val Loss: 0.7296 - Val Acc: 0.7877
# Epoch 50/50 - Loss: 0.0395 - Acc: 0.9900 - Val Loss: 0.8911 - Val Acc: 0.8069
# Iteration 9: Added 10 samples - Accuracy: 80.69%
# Random Iteration 10/48
# Epoch 1/50 - Loss: 2.2708 - Acc: 0.1364 - Val Loss: 2.2103 - Val Acc: 0.1562
# Epoch 25/50 - Loss: 0.0522 - Acc: 0.9909 - Val Loss: 0.8569 - Val Acc: 0.8083
# Epoch 50/50 - Loss: 0.0144 - Acc: 1.0000 - Val Loss: 0.8649 - Val Acc: 0.8173
# Iteration 10: Added 10 samples - Accuracy: 81.73%
# Random Iteration 11/48
# Epoch 1/50 - Loss: 2.2832 - Acc: 0.1167 - Val Loss: 2.2630 - Val Acc: 0.1845
# Epoch 25/50 - Loss: 0.0904 - Acc: 0.9750 - Val Loss: 0.8256 - Val Acc: 0.8040
# Epoch 50/50 - Loss: 0.0330 - Acc: 0.9917 - Val Loss: 1.0332 - Val Acc: 0.8136
# Iteration 11: Added 10 samples - Accuracy: 81.36%
# Random Iteration 12/48
# Epoch 1/50 - Loss: 2.2999 - Acc: 0.1308 - Val Loss: 2.2212 - Val Acc: 0.0981
# Epoch 25/50 - Loss: 0.1591 - Acc: 0.9462 - Val Loss: 0.6556 - Val Acc: 0.8240
# Epoch 50/50 - Loss: 0.0210 - Acc: 0.9923 - Val Loss: 0.8142 - Val Acc: 0.8181
# Iteration 12: Added 10 samples - Accuracy: 81.81%
# Random Iteration 13/48
# Epoch 1/50 - Loss: 2.2883 - Acc: 0.1571 - Val Loss: 2.2458 - Val Acc: 0.2393
# Epoch 25/50 - Loss: 0.1584 - Acc: 0.9429 - Val Loss: 0.7163 - Val Acc: 0.8247
# Epoch 50/50 - Loss: 0.0297 - Acc: 0.9857 - Val Loss: 0.9359 - Val Acc: 0.8190
# Iteration 13: Added 10 samples - Accuracy: 81.90%
# Random Iteration 14/48
# Epoch 1/50 - Loss: 2.2957 - Acc: 0.1000 - Val Loss: 2.2119 - Val Acc: 0.1951
# Epoch 25/50 - Loss: 0.0895 - Acc: 0.9800 - Val Loss: 0.7476 - Val Acc: 0.8186
# Epoch 50/50 - Loss: 0.0265 - Acc: 0.9933 - Val Loss: 0.9663 - Val Acc: 0.8285
# Iteration 14: Added 10 samples - Accuracy: 82.85%
# Random Iteration 15/48
# Epoch 1/50 - Loss: 2.2801 - Acc: 0.1500 - Val Loss: 2.2222 - Val Acc: 0.1742
# Epoch 25/50 - Loss: 0.0736 - Acc: 0.9688 - Val Loss: 0.7878 - Val Acc: 0.8296
# Epoch 50/50 - Loss: 0.0362 - Acc: 0.9812 - Val Loss: 0.7258 - Val Acc: 0.8477
# Iteration 15: Added 10 samples - Accuracy: 84.77%
# Random Iteration 16/48
# Epoch 1/50 - Loss: 2.2892 - Acc: 0.1118 - Val Loss: 2.1938 - Val Acc: 0.2559
# Epoch 25/50 - Loss: 0.0659 - Acc: 0.9824 - Val Loss: 0.6321 - Val Acc: 0.8517
# Epoch 50/50 - Loss: 0.0232 - Acc: 0.9882 - Val Loss: 0.6286 - Val Acc: 0.8696
# Iteration 16: Added 10 samples - Accuracy: 86.96%
# Random Iteration 17/48
# Epoch 1/50 - Loss: 2.2729 - Acc: 0.1333 - Val Loss: 2.1569 - Val Acc: 0.3287
# Epoch 25/50 - Loss: 0.0449 - Acc: 0.9889 - Val Loss: 0.5595 - Val Acc: 0.8666
# Epoch 50/50 - Loss: 0.0231 - Acc: 0.9944 - Val Loss: 0.5795 - Val Acc: 0.8834
# Iteration 17: Added 10 samples - Accuracy: 88.34%
# Random Iteration 18/48
# Epoch 1/50 - Loss: 2.2738 - Acc: 0.1263 - Val Loss: 2.1783 - Val Acc: 0.2742
# Epoch 25/50 - Loss: 0.0578 - Acc: 0.9947 - Val Loss: 0.4994 - Val Acc: 0.8788
# Epoch 50/50 - Loss: 0.0372 - Acc: 0.9895 - Val Loss: 0.5205 - Val Acc: 0.8878
# Iteration 18: Added 10 samples - Accuracy: 88.78%
# Random Iteration 19/48
# Epoch 1/50 - Loss: 2.2917 - Acc: 0.1150 - Val Loss: 2.2176 - Val Acc: 0.1442
# Epoch 25/50 - Loss: 0.0468 - Acc: 0.9900 - Val Loss: 0.5113 - Val Acc: 0.8772
# Epoch 50/50 - Loss: 0.0196 - Acc: 0.9900 - Val Loss: 0.6349 - Val Acc: 0.8713
# Iteration 19: Added 10 samples - Accuracy: 87.13%
# Random Iteration 20/48
# Epoch 1/50 - Loss: 2.2740 - Acc: 0.1619 - Val Loss: 2.1782 - Val Acc: 0.1643
# Epoch 25/50 - Loss: 0.0803 - Acc: 0.9667 - Val Loss: 0.5336 - Val Acc: 0.8791
# Epoch 50/50 - Loss: 0.0495 - Acc: 0.9762 - Val Loss: 0.5710 - Val Acc: 0.8921
# Iteration 20: Added 10 samples - Accuracy: 89.21%
# Random Iteration 21/48
# Epoch 1/50 - Loss: 2.2560 - Acc: 0.1455 - Val Loss: 2.1246 - Val Acc: 0.3186
# Epoch 25/50 - Loss: 0.0570 - Acc: 0.9864 - Val Loss: 0.5035 - Val Acc: 0.8895
# Epoch 50/50 - Loss: 0.0185 - Acc: 0.9955 - Val Loss: 0.5598 - Val Acc: 0.8926
# Iteration 21: Added 10 samples - Accuracy: 89.26%
# Random Iteration 22/48
# Epoch 1/50 - Loss: 2.2537 - Acc: 0.1739 - Val Loss: 2.0815 - Val Acc: 0.3393
# Epoch 25/50 - Loss: 0.0759 - Acc: 0.9783 - Val Loss: 0.4663 - Val Acc: 0.8856
# Epoch 50/50 - Loss: 0.0336 - Acc: 0.9826 - Val Loss: 0.5435 - Val Acc: 0.8941
# Iteration 22: Added 10 samples - Accuracy: 89.41%
# Random Iteration 23/48
# Epoch 1/50 - Loss: 2.2616 - Acc: 0.1417 - Val Loss: 2.0899 - Val Acc: 0.3863
# Epoch 25/50 - Loss: 0.0518 - Acc: 0.9875 - Val Loss: 0.4784 - Val Acc: 0.8875
# Epoch 50/50 - Loss: 0.0147 - Acc: 1.0000 - Val Loss: 0.5337 - Val Acc: 0.9014
# Iteration 23: Added 10 samples - Accuracy: 90.14%
# Random Iteration 24/48
# Epoch 1/50 - Loss: 2.2892 - Acc: 0.1120 - Val Loss: 2.2063 - Val Acc: 0.2479
# Epoch 25/50 - Loss: 0.0741 - Acc: 0.9760 - Val Loss: 0.4963 - Val Acc: 0.8814
# Epoch 50/50 - Loss: 0.0283 - Acc: 0.9840 - Val Loss: 0.5028 - Val Acc: 0.9081
# Iteration 24: Added 10 samples - Accuracy: 90.81%
# Random Iteration 25/48
# Epoch 1/50 - Loss: 2.2479 - Acc: 0.1538 - Val Loss: 2.0009 - Val Acc: 0.3528
# Epoch 25/50 - Loss: 0.0355 - Acc: 0.9923 - Val Loss: 0.4219 - Val Acc: 0.8961
# Epoch 50/50 - Loss: 0.0140 - Acc: 0.9923 - Val Loss: 0.4445 - Val Acc: 0.9058
# Iteration 25: Added 10 samples - Accuracy: 90.58%
# Random Iteration 26/48
# Epoch 1/50 - Loss: 2.2879 - Acc: 0.1148 - Val Loss: 2.1521 - Val Acc: 0.3751
# Epoch 25/50 - Loss: 0.0415 - Acc: 0.9852 - Val Loss: 0.4595 - Val Acc: 0.8918
# Epoch 50/50 - Loss: 0.0550 - Acc: 0.9852 - Val Loss: 0.5165 - Val Acc: 0.9045
# Iteration 26: Added 10 samples - Accuracy: 90.45%
# Random Iteration 27/48
# Epoch 1/50 - Loss: 2.2914 - Acc: 0.1393 - Val Loss: 2.1868 - Val Acc: 0.3285
# Epoch 25/50 - Loss: 0.0350 - Acc: 0.9929 - Val Loss: 0.4913 - Val Acc: 0.8933
# Epoch 50/50 - Loss: 0.0366 - Acc: 0.9786 - Val Loss: 0.5035 - Val Acc: 0.9023
# Iteration 27: Added 10 samples - Accuracy: 90.23%
# Random Iteration 28/48
# Epoch 1/50 - Loss: 2.2658 - Acc: 0.1517 - Val Loss: 2.1082 - Val Acc: 0.1671
# Epoch 25/50 - Loss: 0.0578 - Acc: 0.9793 - Val Loss: 0.4913 - Val Acc: 0.8943
# Epoch 50/50 - Loss: 0.0859 - Acc: 0.9724 - Val Loss: 0.4828 - Val Acc: 0.8992
# Iteration 28: Added 10 samples - Accuracy: 89.92%
# Random Iteration 29/48
# Epoch 1/50 - Loss: 2.2675 - Acc: 0.1767 - Val Loss: 2.0808 - Val Acc: 0.5433
# Epoch 25/50 - Loss: 0.0609 - Acc: 0.9733 - Val Loss: 0.4043 - Val Acc: 0.9063
# Epoch 50/50 - Loss: 0.0521 - Acc: 0.9900 - Val Loss: 0.4345 - Val Acc: 0.9209
# Iteration 29: Added 10 samples - Accuracy: 92.09%
# Random Iteration 30/48
# Epoch 1/50 - Loss: 2.2544 - Acc: 0.1419 - Val Loss: 2.0421 - Val Acc: 0.4552
# Epoch 25/50 - Loss: 0.0642 - Acc: 0.9806 - Val Loss: 0.3463 - Val Acc: 0.9137
# Epoch 50/50 - Loss: 0.0245 - Acc: 0.9935 - Val Loss: 0.4401 - Val Acc: 0.9147
# Iteration 30: Added 10 samples - Accuracy: 91.47%
# Random Iteration 31/48
# Epoch 1/50 - Loss: 2.2029 - Acc: 0.1906 - Val Loss: 1.9063 - Val Acc: 0.5649
# Epoch 25/50 - Loss: 0.0625 - Acc: 0.9719 - Val Loss: 0.4526 - Val Acc: 0.8976
# Epoch 50/50 - Loss: 0.0220 - Acc: 0.9938 - Val Loss: 0.4653 - Val Acc: 0.9098
# Iteration 31: Added 10 samples - Accuracy: 90.98%
# Random Iteration 32/48
# Epoch 1/50 - Loss: 2.2424 - Acc: 0.1485 - Val Loss: 1.9524 - Val Acc: 0.6390
# Epoch 25/50 - Loss: 0.0610 - Acc: 0.9818 - Val Loss: 0.4140 - Val Acc: 0.9070
# Epoch 50/50 - Loss: 0.0220 - Acc: 0.9848 - Val Loss: 0.4872 - Val Acc: 0.9085
# Iteration 32: Added 10 samples - Accuracy: 90.85%
# Random Iteration 33/48
# Epoch 1/50 - Loss: 2.2083 - Acc: 0.1941 - Val Loss: 1.8829 - Val Acc: 0.4809
# Epoch 25/50 - Loss: 0.0387 - Acc: 0.9882 - Val Loss: 0.4239 - Val Acc: 0.9083
# Epoch 50/50 - Loss: 0.0538 - Acc: 0.9794 - Val Loss: 0.3856 - Val Acc: 0.9203
# Iteration 33: Added 10 samples - Accuracy: 92.03%
# Random Iteration 34/48
# Epoch 1/50 - Loss: 2.1633 - Acc: 0.1971 - Val Loss: 1.8437 - Val Acc: 0.4550
# Epoch 25/50 - Loss: 0.0654 - Acc: 0.9743 - Val Loss: 0.3800 - Val Acc: 0.9203
# Epoch 50/50 - Loss: 0.0162 - Acc: 0.9943 - Val Loss: 0.4292 - Val Acc: 0.9244
# Iteration 34: Added 10 samples - Accuracy: 92.44%
# Random Iteration 35/48
# Epoch 1/50 - Loss: 2.1948 - Acc: 0.2139 - Val Loss: 1.8184 - Val Acc: 0.4088
# Epoch 25/50 - Loss: 0.0576 - Acc: 0.9833 - Val Loss: 0.3992 - Val Acc: 0.9107
# Epoch 50/50 - Loss: 0.0656 - Acc: 0.9778 - Val Loss: 0.3680 - Val Acc: 0.9192
# Iteration 35: Added 10 samples - Accuracy: 91.92%
# Random Iteration 36/48
# Epoch 1/50 - Loss: 2.2026 - Acc: 0.1838 - Val Loss: 1.8589 - Val Acc: 0.4058
# Epoch 25/50 - Loss: 0.0348 - Acc: 0.9892 - Val Loss: 0.3098 - Val Acc: 0.9281
# Epoch 50/50 - Loss: 0.0057 - Acc: 0.9973 - Val Loss: 0.3733 - Val Acc: 0.9360
# Iteration 36: Added 10 samples - Accuracy: 93.60%
# Random Iteration 37/48
# Epoch 1/50 - Loss: 2.2164 - Acc: 0.2053 - Val Loss: 1.9239 - Val Acc: 0.4077
# Epoch 25/50 - Loss: 0.1099 - Acc: 0.9605 - Val Loss: 0.3830 - Val Acc: 0.9075
# Epoch 50/50 - Loss: 0.0315 - Acc: 0.9895 - Val Loss: 0.4307 - Val Acc: 0.9120
# Iteration 37: Added 10 samples - Accuracy: 91.20%
# Random Iteration 38/48
# Epoch 1/50 - Loss: 2.2299 - Acc: 0.1692 - Val Loss: 1.9254 - Val Acc: 0.5298
# Epoch 25/50 - Loss: 0.0464 - Acc: 0.9821 - Val Loss: 0.3251 - Val Acc: 0.9257
# Epoch 50/50 - Loss: 0.0439 - Acc: 0.9821 - Val Loss: 0.3182 - Val Acc: 0.9303
# Iteration 38: Added 10 samples - Accuracy: 93.03%
# Random Iteration 39/48
# Epoch 1/50 - Loss: 2.1768 - Acc: 0.2050 - Val Loss: 1.7345 - Val Acc: 0.5737
# Epoch 25/50 - Loss: 0.0625 - Acc: 0.9825 - Val Loss: 0.3450 - Val Acc: 0.9233
# Epoch 50/50 - Loss: 0.0166 - Acc: 0.9950 - Val Loss: 0.4088 - Val Acc: 0.9245
# Iteration 39: Added 10 samples - Accuracy: 92.45%
# Random Iteration 40/48
# Epoch 1/50 - Loss: 2.1636 - Acc: 0.2049 - Val Loss: 1.6617 - Val Acc: 0.5713
# Epoch 25/50 - Loss: 0.0537 - Acc: 0.9878 - Val Loss: 0.3150 - Val Acc: 0.9199
# Epoch 50/50 - Loss: 0.0260 - Acc: 0.9927 - Val Loss: 0.3265 - Val Acc: 0.9324
# Iteration 40: Added 10 samples - Accuracy: 93.24%
# Random Iteration 41/48
# Epoch 1/50 - Loss: 2.1694 - Acc: 0.2357 - Val Loss: 1.7193 - Val Acc: 0.5184
# Epoch 25/50 - Loss: 0.0867 - Acc: 0.9714 - Val Loss: 0.3381 - Val Acc: 0.9194
# Epoch 50/50 - Loss: 0.0128 - Acc: 0.9952 - Val Loss: 0.3435 - Val Acc: 0.9342
# Iteration 41: Added 10 samples - Accuracy: 93.42%
# Random Iteration 42/48
# Epoch 1/50 - Loss: 2.1559 - Acc: 0.2326 - Val Loss: 1.7170 - Val Acc: 0.5050
# Epoch 25/50 - Loss: 0.0456 - Acc: 0.9884 - Val Loss: 0.3096 - Val Acc: 0.9332
# Epoch 50/50 - Loss: 0.0295 - Acc: 0.9953 - Val Loss: 0.3868 - Val Acc: 0.9263
# Iteration 42: Added 10 samples - Accuracy: 92.63%
# Random Iteration 43/48
# Epoch 1/50 - Loss: 2.1585 - Acc: 0.2523 - Val Loss: 1.6882 - Val Acc: 0.6287
# Epoch 25/50 - Loss: 0.0752 - Acc: 0.9773 - Val Loss: 0.3183 - Val Acc: 0.9262
# Epoch 50/50 - Loss: 0.0199 - Acc: 0.9955 - Val Loss: 0.4161 - Val Acc: 0.9302
# Iteration 43: Added 10 samples - Accuracy: 93.02%
# Random Iteration 44/48
# Epoch 1/50 - Loss: 2.1618 - Acc: 0.1867 - Val Loss: 1.7444 - Val Acc: 0.5343
# Epoch 25/50 - Loss: 0.0476 - Acc: 0.9844 - Val Loss: 0.2865 - Val Acc: 0.9307
# Epoch 50/50 - Loss: 0.0268 - Acc: 0.9889 - Val Loss: 0.3483 - Val Acc: 0.9317
# Iteration 44: Added 10 samples - Accuracy: 93.17%
# Random Iteration 45/48
# Epoch 1/50 - Loss: 2.0610 - Acc: 0.2848 - Val Loss: 1.3301 - Val Acc: 0.6385
# Epoch 25/50 - Loss: 0.0428 - Acc: 0.9804 - Val Loss: 0.3654 - Val Acc: 0.9224
# Epoch 50/50 - Loss: 0.0165 - Acc: 0.9935 - Val Loss: 0.3592 - Val Acc: 0.9331
# Iteration 45: Added 10 samples - Accuracy: 93.31%
# Random Iteration 46/48
# Epoch 1/50 - Loss: 2.1062 - Acc: 0.2638 - Val Loss: 1.4680 - Val Acc: 0.7115
# Epoch 25/50 - Loss: 0.0514 - Acc: 0.9830 - Val Loss: 0.3602 - Val Acc: 0.9227
# Epoch 50/50 - Loss: 0.0414 - Acc: 0.9872 - Val Loss: 0.4195 - Val Acc: 0.9272
# Iteration 46: Added 10 samples - Accuracy: 92.72%
# Random Iteration 47/48
# Epoch 1/50 - Loss: 2.1804 - Acc: 0.2271 - Val Loss: 1.8196 - Val Acc: 0.4997
# Epoch 25/50 - Loss: 0.0431 - Acc: 0.9875 - Val Loss: 0.3343 - Val Acc: 0.9283
# Epoch 50/50 - Loss: 0.0195 - Acc: 0.9917 - Val Loss: 0.3305 - Val Acc: 0.9360
# Iteration 47: Added 10 samples - Accuracy: 93.60%
# Random Iteration 48/48
# Epoch 1/50 - Loss: 2.1050 - Acc: 0.2592 - Val Loss: 1.4444 - Val Acc: 0.6362
# Epoch 25/50 - Loss: 0.0338 - Acc: 0.9898 - Val Loss: 0.2550 - Val Acc: 0.9399
# Epoch 50/50 - Loss: 0.0451 - Acc: 0.9857 - Val Loss: 0.2998 - Val Acc: 0.9404
# Iteration 48: Added 10 samples - Accuracy: 94.04%
#
# ===== Completed random acquisition =====
#
# Using device: cuda
# Model directory: models/knowledge_uncertainty/bcd9b1c5-c023-4956-a496-0c882d84fe63
# Knowledge_Uncertainty Iteration 1/48
# Epoch 1/50 - Loss: 2.3051 - Acc: 0.1500 - Val Loss: 2.3007 - Val Acc: 0.0958
# Epoch 25/50 - Loss: 0.0822 - Acc: 1.0000 - Val Loss: 1.6716 - Val Acc: 0.5456
# Epoch 50/50 - Loss: 0.0038 - Acc: 1.0000 - Val Loss: 2.1631 - Val Acc: 0.5770
# 100%|██████████| 20/20 [00:06<00:00,  3.19it/s]
# Iteration 1: Added 10 samples - Accuracy: 57.70%
# Knowledge_Uncertainty Iteration 2/48
# Epoch 1/50 - Loss: 2.3173 - Acc: 0.0667 - Val Loss: 2.2883 - Val Acc: 0.0892
# Epoch 25/50 - Loss: 0.0830 - Acc: 1.0000 - Val Loss: 1.2242 - Val Acc: 0.6562
# Epoch 50/50 - Loss: 0.0104 - Acc: 1.0000 - Val Loss: 1.7828 - Val Acc: 0.6328
# 100%|██████████| 20/20 [00:06<00:00,  3.21it/s]
# Iteration 2: Added 10 samples - Accuracy: 63.28%
# Knowledge_Uncertainty Iteration 3/48
# Epoch 1/50 - Loss: 2.2889 - Acc: 0.0750 - Val Loss: 2.2928 - Val Acc: 0.1135
# Epoch 25/50 - Loss: 0.1532 - Acc: 0.9500 - Val Loss: 1.4558 - Val Acc: 0.6435
# Epoch 50/50 - Loss: 0.0211 - Acc: 1.0000 - Val Loss: 1.3770 - Val Acc: 0.6832
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 3: Added 10 samples - Accuracy: 68.32%
# Knowledge_Uncertainty Iteration 4/48
# Epoch 1/50 - Loss: 2.2985 - Acc: 0.1400 - Val Loss: 2.2832 - Val Acc: 0.1362
# Epoch 25/50 - Loss: 0.1847 - Acc: 0.9600 - Val Loss: 0.9993 - Val Acc: 0.7096
# Epoch 50/50 - Loss: 0.0514 - Acc: 1.0000 - Val Loss: 1.3486 - Val Acc: 0.7247
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 4: Added 10 samples - Accuracy: 72.47%
# Knowledge_Uncertainty Iteration 5/48
# Epoch 1/50 - Loss: 2.3108 - Acc: 0.1000 - Val Loss: 2.2797 - Val Acc: 0.1596
# Epoch 25/50 - Loss: 0.1328 - Acc: 0.9833 - Val Loss: 1.1797 - Val Acc: 0.7111
# Epoch 50/50 - Loss: 0.0414 - Acc: 1.0000 - Val Loss: 1.3561 - Val Acc: 0.7167
# 100%|██████████| 20/20 [00:06<00:00,  3.22it/s]
# Iteration 5: Added 10 samples - Accuracy: 71.67%
# Knowledge_Uncertainty Iteration 6/48
# Epoch 1/50 - Loss: 2.3077 - Acc: 0.1286 - Val Loss: 2.2745 - Val Acc: 0.2373
# Epoch 25/50 - Loss: 0.1234 - Acc: 0.9714 - Val Loss: 1.2180 - Val Acc: 0.6816
# Epoch 50/50 - Loss: 0.0530 - Acc: 0.9714 - Val Loss: 1.2964 - Val Acc: 0.7476
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 6: Added 10 samples - Accuracy: 74.76%
# Knowledge_Uncertainty Iteration 7/48
# Epoch 1/50 - Loss: 2.2980 - Acc: 0.1000 - Val Loss: 2.2698 - Val Acc: 0.2309
# Epoch 25/50 - Loss: 0.0438 - Acc: 1.0000 - Val Loss: 0.9016 - Val Acc: 0.7743
# Epoch 50/50 - Loss: 0.0121 - Acc: 1.0000 - Val Loss: 1.4128 - Val Acc: 0.7381
# 100%|██████████| 20/20 [00:06<00:00,  3.21it/s]
# Iteration 7: Added 10 samples - Accuracy: 73.81%
# Knowledge_Uncertainty Iteration 8/48
# Epoch 1/50 - Loss: 2.3033 - Acc: 0.0778 - Val Loss: 2.2551 - Val Acc: 0.1858
# Epoch 25/50 - Loss: 0.0318 - Acc: 1.0000 - Val Loss: 1.1742 - Val Acc: 0.7511
# Epoch 50/50 - Loss: 0.0421 - Acc: 0.9889 - Val Loss: 1.4425 - Val Acc: 0.7562
# 100%|██████████| 20/20 [00:06<00:00,  3.22it/s]
# Iteration 8: Added 10 samples - Accuracy: 75.62%
# Knowledge_Uncertainty Iteration 9/48
# Epoch 1/50 - Loss: 2.2930 - Acc: 0.1300 - Val Loss: 2.2677 - Val Acc: 0.2298
# Epoch 25/50 - Loss: 0.1231 - Acc: 0.9700 - Val Loss: 1.0999 - Val Acc: 0.7143
# Epoch 50/50 - Loss: 0.0222 - Acc: 1.0000 - Val Loss: 1.2768 - Val Acc: 0.7520
# 100%|██████████| 20/20 [00:06<00:00,  3.21it/s]
# Iteration 9: Added 10 samples - Accuracy: 75.20%
# Knowledge_Uncertainty Iteration 10/48
# Epoch 1/50 - Loss: 2.3047 - Acc: 0.1273 - Val Loss: 2.2453 - Val Acc: 0.2726
# Epoch 25/50 - Loss: 0.0399 - Acc: 0.9909 - Val Loss: 1.1385 - Val Acc: 0.7547
# Epoch 50/50 - Loss: 0.0371 - Acc: 0.9909 - Val Loss: 1.0504 - Val Acc: 0.7845
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 10: Added 10 samples - Accuracy: 78.45%
# Knowledge_Uncertainty Iteration 11/48
# Epoch 1/50 - Loss: 2.2791 - Acc: 0.1500 - Val Loss: 2.2130 - Val Acc: 0.2819
# Epoch 25/50 - Loss: 0.0567 - Acc: 0.9833 - Val Loss: 1.0701 - Val Acc: 0.7747
# Epoch 50/50 - Loss: 0.0360 - Acc: 0.9917 - Val Loss: 1.4112 - Val Acc: 0.7617
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 11: Added 10 samples - Accuracy: 76.17%
# Knowledge_Uncertainty Iteration 12/48
# Epoch 1/50 - Loss: 2.2849 - Acc: 0.1538 - Val Loss: 2.1958 - Val Acc: 0.2832
# Epoch 25/50 - Loss: 0.0958 - Acc: 0.9692 - Val Loss: 0.9408 - Val Acc: 0.7635
# Epoch 50/50 - Loss: 0.0927 - Acc: 0.9769 - Val Loss: 1.3088 - Val Acc: 0.7528
# 100%|██████████| 20/20 [00:06<00:00,  3.22it/s]
# Iteration 12: Added 10 samples - Accuracy: 75.28%
# Knowledge_Uncertainty Iteration 13/48
# Epoch 1/50 - Loss: 2.2891 - Acc: 0.1500 - Val Loss: 2.2408 - Val Acc: 0.2186
# Epoch 25/50 - Loss: 0.0531 - Acc: 0.9857 - Val Loss: 1.0334 - Val Acc: 0.7822
# Epoch 50/50 - Loss: 0.0236 - Acc: 1.0000 - Val Loss: 1.1817 - Val Acc: 0.7851
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 13: Added 10 samples - Accuracy: 78.51%
# Knowledge_Uncertainty Iteration 14/48
# Epoch 1/50 - Loss: 2.2631 - Acc: 0.1733 - Val Loss: 2.1530 - Val Acc: 0.3746
# Epoch 25/50 - Loss: 0.0394 - Acc: 0.9867 - Val Loss: 1.0738 - Val Acc: 0.7798
# Epoch 50/50 - Loss: 0.0043 - Acc: 1.0000 - Val Loss: 1.1047 - Val Acc: 0.7999
# 100%|██████████| 20/20 [00:06<00:00,  3.22it/s]
# Iteration 14: Added 10 samples - Accuracy: 79.99%
# Knowledge_Uncertainty Iteration 15/48
# Epoch 1/50 - Loss: 2.2907 - Acc: 0.1688 - Val Loss: 2.2414 - Val Acc: 0.2980
# Epoch 25/50 - Loss: 0.0699 - Acc: 0.9812 - Val Loss: 1.1366 - Val Acc: 0.7728
# Epoch 50/50 - Loss: 0.0499 - Acc: 0.9812 - Val Loss: 1.0689 - Val Acc: 0.7955
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 15: Added 10 samples - Accuracy: 79.55%
# Knowledge_Uncertainty Iteration 16/48
# Epoch 1/50 - Loss: 2.1953 - Acc: 0.2647 - Val Loss: 1.9444 - Val Acc: 0.4447
# Epoch 25/50 - Loss: 0.0708 - Acc: 0.9824 - Val Loss: 0.9682 - Val Acc: 0.7973
# Epoch 50/50 - Loss: 0.0363 - Acc: 0.9882 - Val Loss: 1.1174 - Val Acc: 0.8071
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 16: Added 10 samples - Accuracy: 80.71%
# Knowledge_Uncertainty Iteration 17/48
# Epoch 1/50 - Loss: 2.2756 - Acc: 0.1500 - Val Loss: 2.1729 - Val Acc: 0.4273
# Epoch 25/50 - Loss: 0.0196 - Acc: 1.0000 - Val Loss: 0.9362 - Val Acc: 0.8151
# Epoch 50/50 - Loss: 0.0049 - Acc: 1.0000 - Val Loss: 1.0852 - Val Acc: 0.8149
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 17: Added 10 samples - Accuracy: 81.49%
# Knowledge_Uncertainty Iteration 18/48
# Epoch 1/50 - Loss: 2.2776 - Acc: 0.1947 - Val Loss: 2.1893 - Val Acc: 0.4528
# Epoch 25/50 - Loss: 0.0744 - Acc: 0.9842 - Val Loss: 0.9030 - Val Acc: 0.8098
# Epoch 50/50 - Loss: 0.0299 - Acc: 0.9842 - Val Loss: 1.0129 - Val Acc: 0.8201
# 100%|██████████| 20/20 [00:06<00:00,  3.22it/s]
# Iteration 18: Added 10 samples - Accuracy: 82.01%
# Knowledge_Uncertainty Iteration 19/48
# Epoch 1/50 - Loss: 2.2833 - Acc: 0.1250 - Val Loss: 2.1904 - Val Acc: 0.4027
# Epoch 25/50 - Loss: 0.0276 - Acc: 0.9900 - Val Loss: 1.0242 - Val Acc: 0.8074
# Epoch 50/50 - Loss: 0.0232 - Acc: 0.9900 - Val Loss: 1.1335 - Val Acc: 0.8165
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 19: Added 10 samples - Accuracy: 81.65%
# Knowledge_Uncertainty Iteration 20/48
# Epoch 1/50 - Loss: 2.2824 - Acc: 0.1619 - Val Loss: 2.1901 - Val Acc: 0.3908
# Epoch 25/50 - Loss: 0.0508 - Acc: 0.9905 - Val Loss: 0.9246 - Val Acc: 0.8032
# Epoch 50/50 - Loss: 0.0228 - Acc: 0.9952 - Val Loss: 0.9114 - Val Acc: 0.8367
# 100%|██████████| 20/20 [00:06<00:00,  3.22it/s]
# Iteration 20: Added 10 samples - Accuracy: 83.67%
# Knowledge_Uncertainty Iteration 21/48
# Epoch 1/50 - Loss: 2.2914 - Acc: 0.1500 - Val Loss: 2.1816 - Val Acc: 0.2793
# Epoch 25/50 - Loss: 0.0437 - Acc: 0.9818 - Val Loss: 0.8241 - Val Acc: 0.8254
# Epoch 50/50 - Loss: 0.0221 - Acc: 0.9955 - Val Loss: 0.9775 - Val Acc: 0.8280
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 21: Added 10 samples - Accuracy: 82.80%
# Knowledge_Uncertainty Iteration 22/48
# Epoch 1/50 - Loss: 2.2256 - Acc: 0.1957 - Val Loss: 2.0065 - Val Acc: 0.3599
# Epoch 25/50 - Loss: 0.0393 - Acc: 0.9913 - Val Loss: 0.7693 - Val Acc: 0.8356
# Epoch 50/50 - Loss: 0.0144 - Acc: 0.9957 - Val Loss: 0.8355 - Val Acc: 0.8387
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 22: Added 10 samples - Accuracy: 83.87%
# Knowledge_Uncertainty Iteration 23/48
# Epoch 1/50 - Loss: 2.2299 - Acc: 0.2000 - Val Loss: 2.0031 - Val Acc: 0.4591
# Epoch 25/50 - Loss: 0.0651 - Acc: 0.9792 - Val Loss: 0.8454 - Val Acc: 0.8214
# Epoch 50/50 - Loss: 0.0392 - Acc: 0.9792 - Val Loss: 0.8390 - Val Acc: 0.8455
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 23: Added 10 samples - Accuracy: 84.55%
# Knowledge_Uncertainty Iteration 24/48
# Epoch 1/50 - Loss: 2.2445 - Acc: 0.1720 - Val Loss: 2.1088 - Val Acc: 0.4422
# Epoch 25/50 - Loss: 0.0456 - Acc: 0.9840 - Val Loss: 0.7725 - Val Acc: 0.8348
# Epoch 50/50 - Loss: 0.0241 - Acc: 0.9920 - Val Loss: 0.9827 - Val Acc: 0.8344
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 24: Added 10 samples - Accuracy: 83.44%
# Knowledge_Uncertainty Iteration 25/48
# Epoch 1/50 - Loss: 2.2567 - Acc: 0.1846 - Val Loss: 2.0545 - Val Acc: 0.4070
# Epoch 25/50 - Loss: 0.0630 - Acc: 0.9846 - Val Loss: 0.7105 - Val Acc: 0.8373
# Epoch 50/50 - Loss: 0.0341 - Acc: 0.9885 - Val Loss: 0.8081 - Val Acc: 0.8502
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 25: Added 10 samples - Accuracy: 85.02%
# Knowledge_Uncertainty Iteration 26/48
# Epoch 1/50 - Loss: 2.2526 - Acc: 0.1556 - Val Loss: 2.0648 - Val Acc: 0.4563
# Epoch 25/50 - Loss: 0.0362 - Acc: 0.9963 - Val Loss: 0.6794 - Val Acc: 0.8556
# Epoch 50/50 - Loss: 0.0194 - Acc: 1.0000 - Val Loss: 0.7311 - Val Acc: 0.8718
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 26: Added 10 samples - Accuracy: 87.18%
# Knowledge_Uncertainty Iteration 27/48
# Epoch 1/50 - Loss: 2.2633 - Acc: 0.2321 - Val Loss: 2.1328 - Val Acc: 0.4942
# Epoch 25/50 - Loss: 0.0512 - Acc: 0.9821 - Val Loss: 0.6484 - Val Acc: 0.8579
# Epoch 50/50 - Loss: 0.0201 - Acc: 0.9964 - Val Loss: 0.7057 - Val Acc: 0.8606
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 27: Added 10 samples - Accuracy: 86.06%
# Knowledge_Uncertainty Iteration 28/48
# Epoch 1/50 - Loss: 2.1325 - Acc: 0.3103 - Val Loss: 1.7242 - Val Acc: 0.4869
# Epoch 25/50 - Loss: 0.0503 - Acc: 0.9897 - Val Loss: 0.6063 - Val Acc: 0.8672
# Epoch 50/50 - Loss: 0.0287 - Acc: 0.9931 - Val Loss: 0.6996 - Val Acc: 0.8727
# 100%|██████████| 20/20 [00:06<00:00,  3.26it/s]
# Iteration 28: Added 10 samples - Accuracy: 87.27%
# Knowledge_Uncertainty Iteration 29/48
# Epoch 1/50 - Loss: 2.2625 - Acc: 0.1633 - Val Loss: 2.0727 - Val Acc: 0.5075
# Epoch 25/50 - Loss: 0.0494 - Acc: 0.9833 - Val Loss: 0.6638 - Val Acc: 0.8504
# Epoch 50/50 - Loss: 0.0376 - Acc: 0.9833 - Val Loss: 0.7048 - Val Acc: 0.8640
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 29: Added 10 samples - Accuracy: 86.40%
# Knowledge_Uncertainty Iteration 30/48
# Epoch 1/50 - Loss: 2.2041 - Acc: 0.2774 - Val Loss: 1.9081 - Val Acc: 0.5853
# Epoch 25/50 - Loss: 0.0487 - Acc: 0.9871 - Val Loss: 0.5256 - Val Acc: 0.8648
# Epoch 50/50 - Loss: 0.0354 - Acc: 0.9806 - Val Loss: 0.7666 - Val Acc: 0.8578
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 30: Added 10 samples - Accuracy: 85.78%
# Knowledge_Uncertainty Iteration 31/48
# Epoch 1/50 - Loss: 2.1779 - Acc: 0.2437 - Val Loss: 1.9080 - Val Acc: 0.3645
# Epoch 25/50 - Loss: 0.0263 - Acc: 0.9938 - Val Loss: 0.6224 - Val Acc: 0.8690
# Epoch 50/50 - Loss: 0.0169 - Acc: 0.9969 - Val Loss: 0.7837 - Val Acc: 0.8686
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 31: Added 10 samples - Accuracy: 86.86%
# Knowledge_Uncertainty Iteration 32/48
# Epoch 1/50 - Loss: 2.1947 - Acc: 0.2364 - Val Loss: 1.9503 - Val Acc: 0.3894
# Epoch 25/50 - Loss: 0.0532 - Acc: 0.9818 - Val Loss: 0.6715 - Val Acc: 0.8589
# Epoch 50/50 - Loss: 0.0087 - Acc: 1.0000 - Val Loss: 0.9007 - Val Acc: 0.8507
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 32: Added 10 samples - Accuracy: 85.07%
# Knowledge_Uncertainty Iteration 33/48
# Epoch 1/50 - Loss: 2.1693 - Acc: 0.3000 - Val Loss: 1.8309 - Val Acc: 0.5915
# Epoch 25/50 - Loss: 0.0445 - Acc: 0.9882 - Val Loss: 0.6516 - Val Acc: 0.8563
# Epoch 50/50 - Loss: 0.0368 - Acc: 0.9912 - Val Loss: 0.6436 - Val Acc: 0.8745
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 33: Added 10 samples - Accuracy: 87.45%
# Knowledge_Uncertainty Iteration 34/48
# Epoch 1/50 - Loss: 2.1329 - Acc: 0.2829 - Val Loss: 1.8079 - Val Acc: 0.4697
# Epoch 25/50 - Loss: 0.0280 - Acc: 0.9914 - Val Loss: 0.5283 - Val Acc: 0.8844
# Epoch 50/50 - Loss: 0.0072 - Acc: 1.0000 - Val Loss: 0.6408 - Val Acc: 0.8897
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 34: Added 10 samples - Accuracy: 88.97%
# Knowledge_Uncertainty Iteration 35/48
# Epoch 1/50 - Loss: 2.2465 - Acc: 0.2583 - Val Loss: 2.0094 - Val Acc: 0.4278
# Epoch 25/50 - Loss: 0.0597 - Acc: 0.9889 - Val Loss: 0.7144 - Val Acc: 0.8500
# Epoch 50/50 - Loss: 0.0190 - Acc: 0.9917 - Val Loss: 0.6699 - Val Acc: 0.8837
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 35: Added 10 samples - Accuracy: 88.37%
# Knowledge_Uncertainty Iteration 36/48
# Epoch 1/50 - Loss: 2.1177 - Acc: 0.2486 - Val Loss: 1.6314 - Val Acc: 0.6241
# Epoch 25/50 - Loss: 0.0519 - Acc: 0.9838 - Val Loss: 0.5537 - Val Acc: 0.8828
# Epoch 50/50 - Loss: 0.0274 - Acc: 0.9865 - Val Loss: 0.5522 - Val Acc: 0.8911
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 36: Added 10 samples - Accuracy: 89.11%
# Knowledge_Uncertainty Iteration 37/48
# Epoch 1/50 - Loss: 2.1577 - Acc: 0.2842 - Val Loss: 1.7602 - Val Acc: 0.5316
# Epoch 25/50 - Loss: 0.0421 - Acc: 0.9842 - Val Loss: 0.5478 - Val Acc: 0.8788
# Epoch 50/50 - Loss: 0.0284 - Acc: 0.9921 - Val Loss: 0.6126 - Val Acc: 0.8891
# 100%|██████████| 20/20 [00:06<00:00,  3.25it/s]
# Iteration 37: Added 10 samples - Accuracy: 88.91%
# Knowledge_Uncertainty Iteration 38/48
# Epoch 1/50 - Loss: 2.1691 - Acc: 0.2308 - Val Loss: 1.7826 - Val Acc: 0.4961
# Epoch 25/50 - Loss: 0.0388 - Acc: 0.9923 - Val Loss: 0.5389 - Val Acc: 0.8796
# Epoch 50/50 - Loss: 0.0310 - Acc: 0.9897 - Val Loss: 0.4949 - Val Acc: 0.8940
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 38: Added 10 samples - Accuracy: 89.40%
# Knowledge_Uncertainty Iteration 39/48
# Epoch 1/50 - Loss: 2.1429 - Acc: 0.2925 - Val Loss: 1.6173 - Val Acc: 0.6330
# Epoch 25/50 - Loss: 0.0702 - Acc: 0.9775 - Val Loss: 0.5191 - Val Acc: 0.8848
# Epoch 50/50 - Loss: 0.0188 - Acc: 0.9950 - Val Loss: 0.6874 - Val Acc: 0.8829
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 39: Added 10 samples - Accuracy: 88.29%
# Knowledge_Uncertainty Iteration 40/48
# Epoch 1/50 - Loss: 2.1196 - Acc: 0.2488 - Val Loss: 1.7264 - Val Acc: 0.4971
# Epoch 25/50 - Loss: 0.0375 - Acc: 0.9878 - Val Loss: 0.4824 - Val Acc: 0.8885
# Epoch 50/50 - Loss: 0.0408 - Acc: 0.9902 - Val Loss: 0.5516 - Val Acc: 0.8948
# 100%|██████████| 20/20 [00:06<00:00,  3.25it/s]
# Iteration 40: Added 10 samples - Accuracy: 89.48%
# Knowledge_Uncertainty Iteration 41/48
# Epoch 1/50 - Loss: 2.0286 - Acc: 0.3333 - Val Loss: 1.3168 - Val Acc: 0.6373
# Epoch 25/50 - Loss: 0.0457 - Acc: 0.9810 - Val Loss: 0.4958 - Val Acc: 0.8972
# Epoch 50/50 - Loss: 0.0098 - Acc: 0.9952 - Val Loss: 0.5802 - Val Acc: 0.8980
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 41: Added 10 samples - Accuracy: 89.80%
# Knowledge_Uncertainty Iteration 42/48
# Epoch 1/50 - Loss: 2.0942 - Acc: 0.3209 - Val Loss: 1.5045 - Val Acc: 0.6068
# Epoch 25/50 - Loss: 0.0398 - Acc: 0.9837 - Val Loss: 0.4997 - Val Acc: 0.8911
# Epoch 50/50 - Loss: 0.0097 - Acc: 0.9977 - Val Loss: 0.6036 - Val Acc: 0.8930
# 100%|██████████| 20/20 [00:06<00:00,  3.25it/s]
# Iteration 42: Added 10 samples - Accuracy: 89.30%
# Knowledge_Uncertainty Iteration 43/48
# Epoch 1/50 - Loss: 2.0970 - Acc: 0.2909 - Val Loss: 1.6853 - Val Acc: 0.5069
# Epoch 25/50 - Loss: 0.0548 - Acc: 0.9795 - Val Loss: 0.5084 - Val Acc: 0.8871
# Epoch 50/50 - Loss: 0.0384 - Acc: 0.9886 - Val Loss: 0.5459 - Val Acc: 0.8948
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 43: Added 10 samples - Accuracy: 89.48%
# Knowledge_Uncertainty Iteration 44/48
# Epoch 1/50 - Loss: 2.0879 - Acc: 0.3444 - Val Loss: 1.4908 - Val Acc: 0.5933
# Epoch 25/50 - Loss: 0.0382 - Acc: 0.9889 - Val Loss: 0.4687 - Val Acc: 0.8950
# Epoch 50/50 - Loss: 0.0100 - Acc: 0.9978 - Val Loss: 0.5460 - Val Acc: 0.8989
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]
# Iteration 44: Added 10 samples - Accuracy: 89.89%
# Knowledge_Uncertainty Iteration 45/48
# Epoch 1/50 - Loss: 2.1031 - Acc: 0.2696 - Val Loss: 1.5788 - Val Acc: 0.5576
# Epoch 25/50 - Loss: 0.0353 - Acc: 0.9957 - Val Loss: 0.4897 - Val Acc: 0.9005
# Epoch 50/50 - Loss: 0.0151 - Acc: 0.9935 - Val Loss: 0.4855 - Val Acc: 0.9056
# 100%|██████████| 20/20 [00:06<00:00,  3.26it/s]
# Iteration 45: Added 10 samples - Accuracy: 90.56%
# Knowledge_Uncertainty Iteration 46/48
# Epoch 1/50 - Loss: 1.9993 - Acc: 0.3617 - Val Loss: 1.2631 - Val Acc: 0.6806
# Epoch 25/50 - Loss: 0.0136 - Acc: 0.9979 - Val Loss: 0.5249 - Val Acc: 0.8993
# Epoch 50/50 - Loss: 0.0159 - Acc: 0.9979 - Val Loss: 0.4599 - Val Acc: 0.9095
# 100%|██████████| 20/20 [00:06<00:00,  3.26it/s]
# Iteration 46: Added 10 samples - Accuracy: 90.95%
# Knowledge_Uncertainty Iteration 47/48
# Epoch 1/50 - Loss: 2.0213 - Acc: 0.2938 - Val Loss: 1.3917 - Val Acc: 0.6182
# Epoch 25/50 - Loss: 0.0536 - Acc: 0.9896 - Val Loss: 0.4490 - Val Acc: 0.8988
# Epoch 50/50 - Loss: 0.0290 - Acc: 0.9917 - Val Loss: 0.4611 - Val Acc: 0.9140
# 100%|██████████| 20/20 [00:06<00:00,  3.27it/s]
# Iteration 47: Added 10 samples - Accuracy: 91.40%
# Knowledge_Uncertainty Iteration 48/48
# Epoch 1/50 - Loss: 2.0824 - Acc: 0.3000 - Val Loss: 1.5071 - Val Acc: 0.6154
# Epoch 25/50 - Loss: 0.0488 - Acc: 0.9898 - Val Loss: 0.4258 - Val Acc: 0.8998
# Epoch 50/50 - Loss: 0.0356 - Acc: 0.9878 - Val Loss: 0.4280 - Val Acc: 0.9093
# 100%|██████████| 20/20 [00:06<00:00,  3.24it/s]
# Iteration 48: Added 10 samples - Accuracy: 90.93%
#
# ===== Completed knowledge_uncertainty acquisition =====

# %% [markdown]
# ### 2.5  Visualise the Results
#
# Now that we have our loop, we can inspect the results of this
# process. We will use seaborn and matplotlib to visualize our
# results. The main result we are interested in is the test accuracy over time
# for both the models trained with a random acquisition function and
# the models trained with data acquired via knowledge uncertainty.
# To visualize this, we define `ActiveLearningVisualizer` that loads the results and
# then returns a plot that shows the accuracy per active learning
# iteration cycle.
#
# We can then use this function to plot the results for all acquisition
# functions:

# %%
from visualise import ActiveLearningVisualizer
import matplotlib.pyplot as plt

# Initialize visualizer
visualizer = ActiveLearningVisualizer(output_dir="output", samples_per_iter=10, initial_samples=20)

# Compare different acquisition strategies
# IMPORTANT: change the uuids according to the ones assigned to each of the models trained
fig_acc, fig_img, imgs = visualizer.compare_from_uuids(
    uuids=["fb390fcb-50c9-491d-94a6-41509d944309",
            "205986fe-75d7-4816-99ae-b18627fb7ce9",
            "bcd9b1c5-c023-4956-a496-0c882d84fe63"],
    acquisition_types=["laplace_uncertainty", "random", "knowledge_uncertainty"]
)

plt.show()
# Out:
# Results saved in output

# %% [markdown]
# **Question 6 (10 marks)**
#
# - What can you conclude from the figure that shows the Accuracy of the different acquisition strategies? (**5 marks**). Use a single sentence.
#
# *Solution*
#
# The acquisition functions based on the Laplace approximation and MC dropout tend to lead to higher accuracies over the test set as compared to the random strategy.
#
# - What can you conclude when comparing the samples of the digits chosen for training by the different Acquisition strategies? (**5 marks**). Use a single sentence.
#
# *Solution*
#
# There is more variability in the samples chosen by the acquisition functions based on a measure of uncertainty when compared to those chosen with the random strategy.
